# %%
# -*- coding: utf-8 -*-

"""
This program makes learning ev-gmm.
"""
# Out:
# '\nThis program makes learning ev-gmm.\n'

# %%
# __future__ module make compatible python2 and python3
from __future__ import division, print_function

# basic modules
import os
import os.path
import time

# for warning ignore
import warnings
#warning.filterwarnings('ignore')

# for file system manupulation 
from shutil import rmtree 
import glob
import argparse

# for save object
import pickle

# for make glaph
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (16, 5)
import librosa.display

# for scientific computing
import numpy as np
from numpy.linalg import norm 
from sklearn.decomposition import PCA
#from sklearn.mixture import GMM # GMM class cannot use after sklearn 0.20.0
import sklearn.mixture
from sklearn.mixture.gaussian_mixture import _compute_precision_cholesky
from sklearn.preprocessing import StandardScaler
import scipy.sparse
from scipy.signal import firwin, lfilter

# for display audio controler
from IPython.display import Audio

# for manuplate audio data
import soundfile as sf
import pyworld as pw
import pysptk
from dtw import dtw
from fastdtw import fastdtw

# %%
class WORLD(object):
    """
    WORLD based speech analyzer and synthezer.
    
    Ref : https://github.com/k2kobayashi/sprocket/
    """
    def __init__(self, fs=16000, fftl=1024, shiftms=5.0, minf0=40.0, maxf0=500.0):
        """
        Parameters
        ----------
        fs : int 
            Sampling frequency 
        fftl : int
            FFT length
        shiftms : float
            Shift length [ms]
        minf0 : float
            Floor in F0 estimation
        maxf0 : float
            Seli in F0 estimation
        """
        
        self.fs = fs
        self.fftl = fftl
        self.shiftms = shiftms
        self.minf0 = minf0
        self.maxf0 = maxf0
        
    def analyze(self, x):
        """
        Analyze acoustic featueres.
        
        Parameters
        ----------
        x : array, shape(`T`)
            monoral speech signal in time domain
        
        Returns
        ----------
        f0 : array, shape(`T`)
            F0 sequence
        sp : array, shape(`T`, `fftl / 2 + 1`)
            Spectral envelope sequence
        ap : array, shape(`T`, `fftl / 2 + 1`)
            aperiodicity sequence
        """
        
        f0, time_axis = pw.harvest(x, self.fs, f0_floor=self.minf0,
                                   f0_ceil=self.maxf0, frame_period=self.shiftms)
        sp = pw.cheaptrick(x, f0, time_axis, self.fs, fft_size=self.fftl)
        ap = pw.d4c(x, f0, time_axis, self.fs, fft_size=self.fftl)
        
        assert sp.shape == ap.shape
        
        return f0, sp, ap
    
    def analyze_f0(self, x):
        """
        Analyze f0.
        
        Parameters
        ----------
        x : array, shape(`T`)
            monoral speech signal in time domain
        
        Returns
        ----------
        f0 : array, shape(`T`)
            F0 sequence
        """

        f0, time_axis = pw.harvest(x, self.fs, f0_floor=self.minf0,
                                   f0_ceil=self.maxf0, frame_period=self.shiftms)
        
        assert f0.shape == x.shape()
        
        return f0
    
    def synthesis(self, f0, sp, ap):
        """
        Re-synthesizes a speech waveform from acoustic featueres.
        
        Parameters
        ----------
        f0 : array, shape(`T`)
            F0 sequence
        sp : array, shape(`T`, `fftl / 2 + 1`)
            Spectral envelope sequence
        ap : array, shape(`T`, `fftl / 2 + 1`)
            aperiodicity sequence
        """

        return pw.synthesize(f0, sp, ap, self.fs, frame_period=self.shiftms)

# %%
class FeatureExtractor(object):
    """
    Analyze acoustic features from a waveform.
    
    This class may have several types of estimeter like WORLD or STRAIGHT.
    Default type is WORLD.
    
    Ref : https://github.com/k2kobayashi/sprocket/
    """
    
    def __init__(self, analyzer='world', fs=16000, fftl=1024, 
                 shiftms=5.0, minf0=50.0, maxf0=500.0):
        """
        Parameters
        ----------
        analyzer : str
            Analyzer
        fs : int 
            Sampling frequency 
        fftl : int
            FFT length
        shiftms : float
            Shift length [ms]
        minf0 : float
            Floor in F0 estimation
        maxf0 : float
            Seli in F0 estimation
        """
        
        self.analyzer = analyzer
        self.fs = fs
        self.fftl = fftl
        self.shiftms = shiftms
        self.minf0 = minf0
        self.maxf0 = maxf0
    
        if self.analyzer == 'world':
            self.analyzer = WORLD(fs=self.fs, fftl=self.fftl, 
                                  minf0=self.minf0, maxf0=self.maxf0, shiftms=self.shiftms)
        else:
            raise('Analyzer Error : not support type, see FeatureExtractor class.')
        
        self._f0 = None
        self._sp = None
        self._ap = None
        
    def analyze(self, x):
        """
        Analyze acoustic featueres.
        
        Parameters
        ----------
        x : array, shape(`T`)
            monoral speech signal in time domain
        
        Returns
        ----------
        f0 : array, shape(`T`)
            F0 sequence
        sp : array, shape(`T`, `fftl / 2 + 1`)
            Spectral envelope sequence
        ap : array, shape(`T`, `fftl / 2 + 1`)
            aperiodicity sequence
        """
        
        self.x = np.array(x, dtype=np.float)
        self._f0, self._sp, self._ap = self.analyzer.analyze(self.x)
        
        # check f0 < 0
        self._f0[self._f0 < 0] = 0
        
        if np.sum(self._f0) == 0.0:
            print("Warning : F0 values are all zero.")
        
        return self._f0, self._sp, self._ap
    
    def analyze_f0(self, x):
        """
        Analyze f0.
        
        Parameters
        ----------
        x : array, shape(`T`)
            monoral speech signal in time domain
        
        Returns
        ----------
        f0 : array, shape(`T`)
            F0 sequence
        """

        self.x = np.array(x, dtype=np.float)
        self._f0 = self.analyzer.analyze_f0(self.x)

        # check f0 < 0
        self._f0[self._f0 < 0] = 0
        
        if np.sum(self._f0) == 0.0:
            print("Warning : F0 values are all zero.")
        
        return self._f0
    
    def mcep(self, dim=24, alpha=0.42):
        """
        Convert mel-cepstrum sequence from spectral envelope.
        
        Parameters
        ----------
        dim : int
            mel-cepstrum dimension
        alpha : float
            parameter of all-path filter
        
        Returns
        ----------
        mcep : array, shape(`T`, `dim + 1`)
            mel-cepstrum sequence
        """        
        
        self._analyzed_check()
        
        return pysptk.sp2mc(self._sp, dim, alpha)
    
    def codeap(self):
        """
        """
        self._analyzed_check()
        
        return pw.code_aperiodicity(self._ap, self.fs)
    
    def npow(self):
        """
        Normalized power sequence from spectral envelope.
        
        Returns
        ----------
        npow : vector, shape(`T`, `1`)
            Normalized power sequence of the given waveform
        """
        
        self._analyzed_check()
        
        npow = np.apply_along_axis(self._spvec2pow, 1, self._sp)
        
        meanpow = np.mean(npow)
        npow = 10.0 * np.log10(npow / meanpow)
        
        return npow
    
    def _spvec2pow(self, specvec):
        """
        """
        fftl2 = len(specvec) - 1
        fftl = fftl2 * 2
        
        power = specvec[0] + specvec[fftl2]
        for k in range(1, fftl2):
            power += 2.0 * specvec[k]
        power /= fftl
        
        return power
        
    def _analyzed_check(self):
        if self._f0 is None and self._sp is None and self._ap is None:
            raise('Call FeatureExtractor.analyze() before this method.')

# %%
class Synthesizer(object):
    """
    Synthesize a waveform from acoustic features.
    
    Ref : https://github.com/k2kobayashi/sprocket/
    """
    def __init__(self, fs=16000, fftl=1024, shiftms=5.0):
        """
        Parameters
        ----------
        fs : int 
            Sampling frequency 
        fftl : int
            FFT length
        shiftms : float
            Shift length [ms]
        """
        
        self.fs = fs
        self.fftl = fftl
        self.shiftms = shiftms
    
    def synthesis(self, f0, mcep, ap, rmcep=None, alpha=0.42):
        """
        Re-synthesizes a speech waveform from acoustic featueres.
        
        Parameters
        ----------
        f0 : array, shape(`T`)
            F0 sequence
        mcep : array, shape(`T`, `dim`)
            mel-cepstrum sequence
        ap : array, shape(`T`, `fftl / 2 + 1`)
            aperiodicity sequence
        rmcep : array, shape(`T`, `dim`)
            array of reference mel-cepstrum sequence
        alpha : float
            parameter of all-path filter
            
        Returns
        ----------
        wav : array,
            syntesized waveform
        """
        
        if rmcep is not None:
            # power modification
            mcep = mod_power(mcep, rmcep, alpha=alpha)
        
        sp = pysptk.mc2sp(mcep, alpha, self.fftl)
        wav = pw.synthesize(f0, sp, ap, self.fs, frame_period=self.shiftms)
        
        return wav
        
    def synthesis_diff(self, x, diffmcep, rmcep=None, alpha=0.42):
        """
        Re-synthesizes a speech waveform from acoustic featueres.
        filtering with a differential mel-cepstrum.
        
        Parameters
        ----------
        x : array, shape(`samples`)
            array of waveform sequence
        diffmcep : array, shape(`T`, `dim`)
            array of differential mel-cepstrum sequence
        rmcep : array, shape(`T`, `dim`)
            array of reference mel-cepstrum sequence
        alpha : float
            parameter of all-path filter
            
        Returns
        ----------
        wav : array,
            syntesized waveform
        """      
        
        x = x.astype(np.float64)
        dim = diffmcep.shape[1] - 1 
        shiftl = int(self.fs / 1000 * self.shiftms)
        
        if rmcep is not None:
            # power modification
            diffmcep = mod_power(rmcep + diffmcep, rmcep, alpha=alpha) - rmcep        
        
        # mc2b = transform mel-cepstrum to MLSA digital filter coefficients.
        b = np.apply_along_axis(pysptk.mc2b, 1, diffmcep, alpha)
        
        mlsa_fil = pysptk.synthesis.Synthesizer(pysptk.synthesis.MLSADF(dim, alpha=alpha),
                                                shiftl)
        wav = mlsa_fil.synthesis(x, b)
        
        return wav
    
    def synthesis_sp(self, f0, sp, ap):
        """
        Re-synthesizes a speech waveform from acoustic featueres.
        
        Parameters
        ----------
        f0 : array, shape(`T`)
            F0 sequence
        spc : array, shape(`T`, `dim`)
            mel-cepstrum sequence
        ap : array, shape(`T`, `fftl / 2 + 1`)
            aperiodicity sequence
            
        Returns
        ----------
        wav : array,
            syntesized waveform
        """      
        
        wav = pw.synthesize(f0, sp, ap, self.fs, frame_period=self.shiftms)
        
        return wav
    
def mod_power(cvmcep, rmcep, alpha=0.42, irlen=256):
    """
    power modification based on inpuulse responce

    Parameters
    ----------
    cvmcep : array, shape(`T`, `dim`)
        array of converted mel-cepstrum
    rmcep : arraym shape(`T`, `dim`)
        array of reference mel-cepstrum
    alpha : float
        parameter of all-path filter
    irlen : int
        Length for IIR filter

    Returns
    ----------
    modified_cvmcep : array, shape(`T`, `dim`)
        array of power modified converted mel-cepstrum
    """

    if rmcep.shape != cvmcep.shape:
        raise ValueError(
            "The shape of the converted and reference mel-cepstrum are different : {} / {}.format(cvmcep.shape, rmcep.shape)"
        )

    # mc2e = Compute energy from mel-cepstrum. e-option
    cv_e = pysptk.mc2e(cvmcep, alpha=alpha, irlen=irlen)
    r_e = pysptk.mc2e(rmcep, alpha=alpha, irlen=irlen)

    dpow = np.log(r_e / cv_e) / 2

    modified_cvmcep = np.copy(cvmcep)
    modified_cvmcep[:, 0] += dpow

    return modified_cvmcep

# %%
# def util methods
def melcd(array1, array2):
    """
    calculate mel-cepstrum distortion
    
    Parameters
    ----------
    array1, array2 : array, shape(`T`, `dim`) or shape(`dim`)
        Array of original and target.
    
    Returns
    ----------
    mcd : scala, number > 0
        Scala of mel-cepstrum distoriton
    """
    if array1.shape != array2.shape:
        raise ValueError(
            "The shape of both array are different : {} / {}.format(array1.shape,array2.shape)"
        )    
   
    if array1.ndim == 2:
        diff = array1 - array2
        mcd = 10.0 / np.log(10) * np.mean(np.sqrt(2.0 * np.sum(diff ** 2, axis=1)))
    elif array1.ndim == 1:
        diff = array1 - array2
        mcd = 10.0 / np.log(10) * np.sqrt(2.0 * np.sum(diff ** 2))
    else:
        raise ValueError("Dimension mismatch.")
        
    return mcd

def delta(data, win=[-1.0, 1.0, 0]):
    """
    calculate delta component
    
    Parameters
    ----------
    data : array, shape(`T`, `dim`)
        Array of static matrix sequence.
    win : array, shape(`3`)
        The shape of window matrix.
    
    Returns
    ----------
    delta : array, shape(`T`, `dim`)
        Array of delta matrix sequence.
    """
    
    if data.ndim == 1:
        # change vector into 1d-array
        T = len(data)
        dim = data.ndim
        data = data.reshape(T, dim)
    else:
        T, dim = data.shape
    
    win = np.array(win, dtype=np.float64)
    delta = np.zeros((T, dim))
    
    delta[0] = win[0] * data[0] + win[1] * data[1]
    delta[-1] = win[0] * data[-2] + win[1] * data[-1]
    
    for i in range(len(win)):
        delta[1:T - 1] += win[i] * delta[i:T - 2 + i]
    
    return delta

def static_delta(data, win=[-1.0, 1.0, 0]):
    """
    calculate static and delta component
    
    Parameters
    ----------
    data : array, shape(`T`, `dim`)
        Array of static matrix sequence.
    win : array, shape(`3`)
        The shape of window matrix.
    
    Returns
    ----------
    sddata : array, shape(`T`, `dim * 2`)
        Array of static and delta matrix sequence.
    """
    
    sddata = np.c_[data, delta(data, win)]
    
    assert sddata.shape[1] == data.shape[1] * 2
    
    return sddata

def construct_static_and_delta_matrix(T, D, win=[-1.0, 1.0, 0]):
    """
    calculate static and delta transformation matrix
    
    Parameters
    ----------
    T : scala, `T`
        Scala of time length
    D : scala, `D`
        Scala of the number of dimension.
    win : array, shape(`3`)
        The shape of window matrix.
    
    Returns
    ----------
    W : array, shape(`2 * D * T`, `D * T`)
        Array of static and delta transformation matrix.
    """
    
    static = [0, 1, 0]
    delta = win
    assert len(static) == len(delta)
    
    # generate full W
    DT = D * T
    ones = np.ones(DT)
    row = np.arange(2 * DT).reshape(2 * T, D) # generate serial numbers
    static_row = row[::2] # [1,2,3,4,5] => [1,3,5]
    delta_row = row[1::2] # [1,2,3,4,5] => [2,4]
    col = np.arange(DT)
    
    data = np.array([ones * static[0], ones * static[1],
                      ones * static[2], ones * delta[0],
                      ones * delta[1], ones * delta[2]]).flatten()
    row = np.array([[static_row] * 3, [delta_row] * 3]).flatten()
    col = np.array([[col - D, col, col + D] * 2]).flatten()

    # remove component at first and end frame
    valid_idx = np.logical_not(np.logical_or(col < 0, col >= DT))
    
    W = scipy.sparse.csr_matrix(
        (data[valid_idx], (row[valid_idx], col[valid_idx])), shape=(2 * DT, DT))
    W.eliminate_zeros()
    
    return W
    
def extfrm(data, npow, power_threshold=-20):
    """
    Extract frame over the power threshold
    
    Parameters
    ----------
    data : array, shape(`T`, `dim`)
        array of input data
    npow : array, shape(`T`)
        vector of normalized power sequence
    threshold : scala
        scala of power threshold [dB]
        
    Returns
    ----------
    data : array, shape(`T_ext`, `dim`)
        remaining data after extracting frame
        `T_ext` <= `T`
    """
    T = data.shape[0]
    if T != len(npow):
        raise("Length of two vectors is different.")
        
    valid_index = np.where(npow > power_threshold)
    extdata = data[valid_index]
    assert extdata.shape[0] <= T
    
    return extdata

def estimate_twf(orgdata, tardata, distance='melcd', fast=True, otflag=None):
    """
    time warping function estimator
    
    Parameters
    ----------
    orgdata : array, shape(`T_org`, `dim`)
        array of source feature
    tardata : array, shape(`T_tar`, `dim`)
        array of target feature
    distance : str 
        distance function
    fast : bool
        use fastdtw instead of dtw
    otflag : str
        Alignment into the length of specification
        'org' : alignment into original length
        'tar' : alignment into target length   
    
    Returns
    ----------
    twf : array, shape(`2`, `T`)
        time warping function between original and target
    """
    
    if distance == 'melcd':
        def distance_func(x, y): return melcd(x, y)
    else:
        raise ValueError('this distance method is not support.')
    
    if fast:
        _, path = fastdtw(orgdata, tardata, dist=distance_func)
        twf = np.array(path).T
    else:
        _, _, _, twf = dtw(orgdata, tardata, distance_func) 
        
    if otflag is not None:
        twf = modify_twf(twf, otflag=otflag)
    
    return twf

def align_data(org_data, tar_data, twf):
    """
    get aligned joint feature vector
    
    Parameters
    ----------
    org_data : array, shape(`T_org`, `dim_org`)
        Acoustic feature vector of original speaker
    tar_data : array, shape(`T_tar`, `dim_tar`)
        Acoustic feature vector of target speaker
    twf : array, shape(`2`, `T`)
        time warping function between original and target
        
    Returns
    ----------
    jdata : array, shape(`T_new`, `dim_org + dim_tar`)
        Joint feature vector between source and target
    """
    
    jdata = np.c_[org_data[twf[0]], tar_data[twf[1]]]
    return jdata

def modify_twf(twf, otflag=None):
    """
    align specified length
    
    Parameters
    ----------
    twf : array, shape(`2`, `T`)
        time warping function between original and target
    otflag : str
        Alignment into the length of specification
        'org' : alignment into original length
        'tar' : alignment into target length   
    
    Returns
    ----------
    mod_twf : array, shape(`2`, `T_new`)
        time warping function of modified alignment
    """
    
    if otflag == 'org':
        of, indice = np.unique(twf[0], return_index=True)
        mod_twf = np.c_[of, twf[1][indice]].T
    elif otflag == 'tar':
        tf, indice = np.unique(twf[1], return_index=True)
        mod_twf = np.c_[twf[0][indice], tf].T 
    
    return mod_twf

def low_cut_filter(x, fs, cutoff=70):
    """
    low cut filter
    
    Parameters
    ----------
    x : array, shape('samples')
        waveform sequence
    fs : array, int
        Sampling frequency
    cutoff : float
        cutoff frequency of low cut filter
    
    Returns
    ----------
    lct_x : array, shape('samples')
        Low cut filtered waveform sequence
    """
    
    nyquist = fs // 2
    norm_cutoff = cutoff / nyquist
    
    # low cut filter
    fil = firwin(255, norm_cutoff, pass_zero=False)
    lct_x = lfilter(fil, 1, x)
    
    return lct_x

def extsddata(data, npow, power_threshold=-20):
    """
    get power extract static and delta feature vector
    
    Parameters
    ----------
    data : array, shape(`T`, `dim`)
        acoustic feature vector
    npow : array, shape(`T`)
        normalized power vector
    power_threshold : float
        power threshold
    
    Returns
    ----------
    extsddata : array, shape(`T_new`, `dim * 2`)
        silence remove static and delta feature vector
    """
    
    extsddata = extfrm(static_delta(data), npow, power_threshold=power_threshold)
    return extsddata

def transform_jnt(array_list):
    num_files = len(array_list)
    for i in range(num_files):
        if i == 0:
            jnt = array_list[i]
        else:
            jnt = np.r_[jnt, array_list[i]]
    return jnt

# %%
class F0statistics(object):
    """
    Estimate F0 statistics and convert F0
    """
    def __init__(self):
        pass
    
    def estimate(self, f0list):
        """
        estimate F0 statistics from list of f0
        
        Parameters
        ----------
        f0list : list, shape(`f0num`)
            List of several F0 sequence
        
        Returns
        ----------
        f0stats : array, shape(`[mean, std]`)
            values of mean and standard deviation for log f0
        """
        
        n_files = len(f0list)
        for i in range(n_files):
            f0 = f0list[i]
            nonzero_indices = np.nonzero(f0)
            if i == 0:
                f0s = np.log(f0[nonzero_indices])
            else:
                f0s = np.r_[f0s, np.log(f0[nonzero_indices])]
        
        f0stats = np.array([np.mean(f0s), np.std(f0s)])
        
        return f0stats

    def convert(self, f0, orgf0stats, tarf0stats):
        """
        convert F0 based on F0 statistics
        
        Parameters
        ----------
        f0 : array, shape(`T`, `1`)
            array of F0 sequence
        orgf0stats : array, shape(`[mean, std]`)
            vectors of mean and standard deviation of log f0 for original speaker
        tarf0stats : array, shape(`[mean, std]`)
            vectors of mean and standard deviation of log f0 for target speaker
        
        Returns
        ----------
        cvf0 : array, shape(`T`, `1`)
            array of converted F0 sequence
        """
        
        # get length and dimension
        T = len(f0)
        
        # perform f0 conversion
        cvf0 = np.zeros(T)
        
        nonzero_indices  = f0 > 0
        cvf0[nonzero_indices] = np.exp((tarf0stats[1] / orgf0stats[1]) 
                                       * (np.log(f0[nonzero_indices])) 
                                       - orgf0stats[0] + tarf0stats[0])
        
        return cvf0

# %%
class GV(object):
    """
    Estimate statistics and perform postfilter based on the GV statistics.
    """
    def __init__(self):
        pass
    
    def estimate(self, datalist):
        """
        estimate GV statistics from list of data
        
        Parameters
        ----------
        datalist : list, shape(`num_data`)
            List of several data ([T, dim]) sequence
        
        Returns
        ----------
        gvstats : array, shape(`2`, `dim`)
            array of mean and standard deviation for GV
        """
        
        n_files = len(datalist)
        
        var = []
        for i in range(n_files):
            data = datalist[i]
            var.append(np.var(data, axis=0))
            
        # calculate vm and vv
        vm = np.mean(np.array(var), axis=0)
        vv = np.var(np.array(var), axis=0)
        gvstats = np.r_[vm, vv]
        gvstats = gvstats.reshape(2, len(vm))
        
        return gvstats

    def postfilter(self, data, gvstats, cvgvstats=None, alpha=1.0, startdim=1):
        """
        perform postfilter based on GV statistics into data
        
        Parameters
        ----------
        data : array, shape(`T`, `dim`)
            array of data sequence
        gvstats : array, shape(`2`, `dim`)
            array of mean and variance for target GV
        cvgvstats : array, shape(`2`, `dim`)
            array of mean and variance for converted GV
        alpha : float
            morphing coefficient between GV transformed data and data.
            alpha * gvpf(data) + (1 - alpha) * data
        startdim : int
            start dimension to perform GV postfilter
        
        Returns
        ----------
        filtered_data : array, shape(`T`, `data`)
            array of GV postfiltered data sequnece
        """
        
        # get length and dimension
        T, dim = data.shape
        assert gvstats is not None
        assert dim == gvstats.shape[1]
        
        # calculate statics of input data
        datamean = np.mean(data, axis=0)
        
        if cvgvstats is None:
            # use variance of the given data
            datavar = np.var(data, axis=0)
        else:
            # use variance of trained gv stats
            datavar = cvgvstats[0]
        
        # perform GV postfilter
        filterd = np.sqrt(gvstats[0, startdim:] / datavar[startdim:]) * (data[:, startdim:] - datamean[startdim:]) + datamean[startdim:]
        
        filterd_data = np.c_[data[:, :startdim], filterd]
        
        return alpha * filterd_data + (1 - alpha) * data

# %%
# 0. config path
__versions = "pre-stored-jp"
__same_path = "./utterance/" + __versions + "/"
pre_stored_source_list = __same_path + 'pre-source/**/V01/T01/**/*.wav'
pre_stored_list = __same_path + "pre/**/V01/T01/**/*.wav"
output_path = __same_path + "output/"

# 1. estimate features
feat = FeatureExtractor()
synthesizer = Synthesizer()

org_f0list = None
org_splist = None
org_mceplist = None
org_aplist = None
org_npowlist = None
org_codeaplist = None

if os.path.exists(output_path + "_org_f0.pickle") \
    and os.path.exists(output_path + "_org_sp.pickle") \
    and os.path.exists(output_path + "_org_ap.pickle") \
    and os.path.exists(output_path + "_org_mcep.pickle") \
    and os.path.exists(output_path + "_org_npow.pickle") \
    and os.path.exists(output_path + "_org_codeap.pickle"):
        
    with open(output_path + "_org_f0.pickle", 'rb') as f:    
        org_f0list = pickle.load(f)
    with open(output_path + "_org_sp.pickle", 'rb') as f:   
        org_splist = pickle.load(f)
    with open(output_path + "_org_ap.pickle", 'rb') as f:  
        org_aplist = pickle.load(f)
    with open(output_path + "_org_mcep.pickle", 'rb') as f:  
        org_mceplist = pickle.load(f)
    with open(output_path + "_org_npow.pickle", 'rb') as f:  
        org_npowlist = pickle.load(f)
    with open(output_path + "_org_codeap.pickle", 'rb') as f:  
        org_codeaplist = pickle.load(f) 
else:
    org_f0list = []
    org_splist = []
    org_mceplist = []
    org_aplist = []
    org_npowlist = []
    org_codeaplist = []
    for files in sorted(glob.iglob(pre_stored_source_list, recursive=True)):
        wavf = files
        x, fs = sf.read(wavf)
        x = np.array(x, dtype=np.float)
        x = low_cut_filter(x, fs, cutoff=70)
        assert fs == 16000

        print("extract acoustic featuers: " + wavf)

        f0, sp, ap = feat.analyze(x)
        mcep = feat.mcep()
        npow = feat.npow()
        codeap = feat.codeap()
        #name, ext = os.path.splitext(wavf)
        #np.save(name + "_or_f0", f0)
        #np.save(name + "_or_sp", sp)
        #np.save(name + "_or_ap", ap)
        #np.save(name + "_or_mcep", mcep)
        #np.save(name + "_or_codeap", codeap)
        org_f0list.append(f0)
        org_splist.append(sp)
        org_mceplist.append(mcep)
        org_aplist.append(ap)
        org_npowlist.append(npow)
        org_codeaplist.append(codeap)

        #wav = synthesizer.synthesis(f0, mcep, ap)
        #wav = np.clip(wav, -32768, 32767)
        #sf.write(name + "_ansys.wav", wav, fs)

    with open(output_path + "_org_f0.pickle", 'wb') as f:    
        pickle.dump(org_f0list, f)
    with open(output_path + "_org_sp.pickle", 'wb') as f:   
        pickle.dump(org_splist, f)
    with open(output_path + "_org_npow.pickle", 'wb') as f:   
        pickle.dump(org_npowlist, f)
    with open(output_path + "_org_ap.pickle", 'wb') as f:  
        pickle.dump(org_aplist, f)
    with open(output_path + "_org_mcep.pickle", 'wb') as f:  
        pickle.dump(org_mceplist, f)
    with open(output_path + "_org_codeap.pickle", 'wb') as f:  
        pickle.dump(org_codeaplist, f) 

mid_f0list = None
mid_mceplist = None
mid_aplist = None
mid_npowlist = None
mid_splist = None
mid_codeaplist = None        

if os.path.exists(output_path + "_mid_f0.pickle") \
    and os.path.exists(output_path + "_mid_sp_0_.pickle") \
    and os.path.exists(output_path + "_mid_ap_0_.pickle") \
    and os.path.exists(output_path + "_mid_mcep.pickle") \
    and os.path.exists(output_path + "_mid_npow.pickle") \
    and os.path.exists(output_path + "_mid_codeap.pickle"):
        
    with open(output_path + "_mid_f0.pickle", 'rb') as f:    
        mid_f0list = pickle.load(f)
    for i in range(0, len(org_splist)*21, len(org_splist)):  
        with open(output_path + "_mid_sp_{}_.pickle".format(i), 'rb') as f:
            temp_splist = pickle.load(f)
            if mid_splist is None:
                mid_splist = temp_splist
            else:
                mid_splist = mid_splist + temp_splist
    for i in range(0, len(org_aplist)*21, len(org_aplist)):  
        with open(output_path + "_mid_ap_{}_.pickle".format(i), 'rb') as f:
            temp_aplist = pickle.load(f)
            if mid_aplist is None:
                mid_aplist = temp_aplist
            else:
                mid_aplist = mid_aplist + temp_aplist    
    with open(output_path + "_mid_mcep.pickle", 'rb') as f:  
        mid_mceplist = pickle.load(f)
    with open(output_path + "_mid_npow.pickle", 'rb') as f:  
        mid_npowlist = pickle.load(f)
    with open(output_path + "_mid_codeap.pickle", 'rb') as f:  
        mid_codeaplist = pickle.load(f) 
else:        
    mid_f0list = []
    mid_mceplist = []
    mid_aplist = []
    mid_npowlist = []
    mid_splist = []
    mid_codeaplist = []

    for files in sorted(glob.iglob(pre_stored_list, recursive=True)):
        wavf = files
        x, fs = sf.read(wavf)
        x = np.array(x, dtype=np.float)
        x = low_cut_filter(x, fs, cutoff=70)
        assert fs == 16000

        print("extract acoustic featuers: " + wavf)

        f0, sp, ap = feat.analyze(x)
        mcep = feat.mcep()
        npow = feat.npow()
        codeap = feat.codeap()
        name, ext = os.path.splitext(wavf)
        #np.save(name + "_or_f0", f0)
        #np.save(name + "_or_sp", sp)
        #np.save(name + "_or_ap", ap)
        #np.save(name + "_or_mcep", mcep)
        #np.save(name + "_or_codeap", codeap)
        mid_f0list.append(f0)
        mid_splist.append(sp)
        mid_mceplist.append(mcep)
        mid_aplist.append(ap)
        mid_npowlist.append(npow)
        mid_codeaplist.append(codeap)

        #wav = synthesizer.synthesis(f0, mcep, ap)
        #wav = np.clip(wav, -32768, 32767)
        #sf.write(name + "_ansys.wav", wav, fs)
        
    with open(output_path + "_mid_f0.pickle", 'wb') as f:
        print(f)
        pickle.dump(mid_f0list, f)
    with open(output_path + "_mid_npow.pickle", 'wb') as f:
        print(f)
        pickle.dump(mid_npowlist, f)
    for i in range(0, len(mid_splist), len(org_splist)):
        with open(output_path + "_mid_sp_{}_.pickle".format(i), 'wb') as f:   
            print(f)
            pickle.dump(mid_splist[i:i+len(org_splist)], f)
    for i in range(0, len(mid_aplist), len(org_aplist)):
        with open(output_path + "_mid_ap_{}_.pickle".format(i), 'wb') as f:
            print(f)
            pickle.dump(mid_aplist[i:i+len(org_aplist)], f)
    with open(output_path + "_mid_mcep.pickle", 'wb') as f:
        print(f)
        pickle.dump(mid_mceplist, f)
    with open(output_path + "_mid_codeap.pickle", 'wb') as f:
        print(f)
        pickle.dump(mid_codeaplist, f)
# Out:
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/ATR503/A/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/ATR503/A/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/ATR503/A/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/ATR503/A/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/ATR503/A/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/ATR503/A/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/ATR503/A/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/ATR503/A/A20.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/ATR503/A/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/ATR503/A/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/ATR503/A/A25.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/ATR503/A/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/ATR503/A/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSPBOBAMA1/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSPBOBAMA1/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSPBOBAMA1/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSPBOBAMA1/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSPBOBAMA1/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A02.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A05.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A06.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A07.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A08.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A10.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A12.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A13.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A17.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A18.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A29.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A31.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A33.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre-source/EJM10/V01/T01/JSUS/000/A35.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/ATR503/A/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/ATR503/A/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/ATR503/A/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/ATR503/A/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/ATR503/A/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/ATR503/A/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/ATR503/A/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/ATR503/A/A20.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/ATR503/A/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/ATR503/A/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/ATR503/A/A25.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/ATR503/A/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/ATR503/A/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSPBOBAMA1/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSPBOBAMA1/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSPBOBAMA1/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSPBOBAMA1/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSPBOBAMA1/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A02.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A05.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A06.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A07.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A08.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A10.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A12.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A13.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A17.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A18.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A29.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A31.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A33.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF02/V01/T01/JSUS/000/A35.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/ATR503/A/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/ATR503/A/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/ATR503/A/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/ATR503/A/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/ATR503/A/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/ATR503/A/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/ATR503/A/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/ATR503/A/A20.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/ATR503/A/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/ATR503/A/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/ATR503/A/A25.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/ATR503/A/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/ATR503/A/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSPBOBAMA1/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSPBOBAMA1/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSPBOBAMA1/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSPBOBAMA1/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSPBOBAMA1/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A02.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A05.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A06.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A07.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A08.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A10.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A12.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A13.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A17.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A18.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A29.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A31.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A33.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF03/V01/T01/JSUS/000/A35.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/ATR503/A/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/ATR503/A/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/ATR503/A/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/ATR503/A/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/ATR503/A/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/ATR503/A/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/ATR503/A/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/ATR503/A/A20.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/ATR503/A/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/ATR503/A/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/ATR503/A/A25.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/ATR503/A/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/ATR503/A/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSPBOBAMA1/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSPBOBAMA1/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSPBOBAMA1/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSPBOBAMA1/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSPBOBAMA1/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A02.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A05.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A06.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A07.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A08.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A10.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A12.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A13.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A17.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A18.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A29.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A31.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A33.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF04/V01/T01/JSUS/000/A35.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/ATR503/A/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/ATR503/A/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/ATR503/A/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/ATR503/A/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/ATR503/A/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/ATR503/A/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/ATR503/A/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/ATR503/A/A20.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/ATR503/A/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/ATR503/A/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/ATR503/A/A25.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/ATR503/A/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/ATR503/A/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSPBOBAMA1/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSPBOBAMA1/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSPBOBAMA1/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSPBOBAMA1/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSPBOBAMA1/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A02.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A05.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A06.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A07.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A08.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A10.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A12.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A13.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A17.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A18.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A29.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A31.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A33.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF05/V01/T01/JSUS/000/A35.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/ATR503/A/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/ATR503/A/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/ATR503/A/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/ATR503/A/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/ATR503/A/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/ATR503/A/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/ATR503/A/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/ATR503/A/A20.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/ATR503/A/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/ATR503/A/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/ATR503/A/A25.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/ATR503/A/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/ATR503/A/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSPBOBAMA1/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSPBOBAMA1/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSPBOBAMA1/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSPBOBAMA1/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSPBOBAMA1/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A02.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A05.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A06.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A07.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A08.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A10.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A12.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A13.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A17.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A18.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A29.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A31.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A33.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF06/V01/T01/JSUS/000/A35.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/ATR503/A/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/ATR503/A/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/ATR503/A/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/ATR503/A/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/ATR503/A/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/ATR503/A/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/ATR503/A/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/ATR503/A/A20.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/ATR503/A/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/ATR503/A/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/ATR503/A/A25.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/ATR503/A/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/ATR503/A/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSPBOBAMA1/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSPBOBAMA1/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSPBOBAMA1/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSPBOBAMA1/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSPBOBAMA1/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A02.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A05.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A06.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A07.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A08.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A10.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A12.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A13.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A17.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A18.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A29.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A31.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A33.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF08/V01/T01/JSUS/000/A35.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/ATR503/A/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/ATR503/A/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/ATR503/A/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/ATR503/A/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/ATR503/A/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/ATR503/A/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/ATR503/A/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/ATR503/A/A20.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/ATR503/A/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/ATR503/A/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/ATR503/A/A25.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/ATR503/A/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/ATR503/A/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSPBOBAMA1/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSPBOBAMA1/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSPBOBAMA1/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSPBOBAMA1/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSPBOBAMA1/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A02.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A05.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A06.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A07.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A08.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A10.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A12.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A13.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A17.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A18.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A29.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A31.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A33.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF09/V01/T01/JSUS/000/A35.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/ATR503/A/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/ATR503/A/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/ATR503/A/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/ATR503/A/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/ATR503/A/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/ATR503/A/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/ATR503/A/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/ATR503/A/A20.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/ATR503/A/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/ATR503/A/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/ATR503/A/A25.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/ATR503/A/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/ATR503/A/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSPBOBAMA1/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSPBOBAMA1/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSPBOBAMA1/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSPBOBAMA1/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSPBOBAMA1/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A02.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A05.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A06.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A07.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A08.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A10.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A12.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A13.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A17.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A18.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A29.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A31.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A33.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF10/V01/T01/JSUS/000/A35.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/ATR503/A/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/ATR503/A/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/ATR503/A/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/ATR503/A/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/ATR503/A/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/ATR503/A/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/ATR503/A/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/ATR503/A/A20.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/ATR503/A/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/ATR503/A/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/ATR503/A/A25.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/ATR503/A/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/ATR503/A/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSPBOBAMA1/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSPBOBAMA1/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSPBOBAMA1/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSPBOBAMA1/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSPBOBAMA1/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A02.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A05.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A06.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A07.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A08.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A10.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A12.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A13.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A17.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A18.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A29.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A31.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A33.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF101/V01/T01/JSUS/000/A35.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/ATR503/A/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/ATR503/A/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/ATR503/A/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/ATR503/A/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/ATR503/A/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/ATR503/A/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/ATR503/A/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/ATR503/A/A20.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/ATR503/A/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/ATR503/A/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/ATR503/A/A25.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/ATR503/A/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/ATR503/A/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSPBOBAMA1/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSPBOBAMA1/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSPBOBAMA1/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSPBOBAMA1/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSPBOBAMA1/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A02.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A05.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A06.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A07.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A08.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A10.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A12.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A13.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A17.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A18.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A29.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A31.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A33.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF102/V01/T01/JSUS/000/A35.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/ATR503/A/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/ATR503/A/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/ATR503/A/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/ATR503/A/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/ATR503/A/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/ATR503/A/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/ATR503/A/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/ATR503/A/A20.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/ATR503/A/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/ATR503/A/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/ATR503/A/A25.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/ATR503/A/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/ATR503/A/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/JSPBOBAMA1/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/JSPBOBAMA1/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/JSPBOBAMA1/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/JSPBOBAMA1/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/JSPBOBAMA1/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/JSUS/000/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/JSUS/000/A02.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/JSUS/000/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/JSUS/000/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/JSUS/000/A05.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/JSUS/000/A06.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/JSUS/000/A07.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/JSUS/000/A08.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/JSUS/000/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/JSUS/000/A10.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/JSUS/000/A12.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJF11/V01/T01/JSUS/000/A13.wav
# ...
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/ATR503/A/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/ATR503/A/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/ATR503/A/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/ATR503/A/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/ATR503/A/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/ATR503/A/A20.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/ATR503/A/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/ATR503/A/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/ATR503/A/A25.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/ATR503/A/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/ATR503/A/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSPBOBAMA1/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSPBOBAMA1/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSPBOBAMA1/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSPBOBAMA1/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSPBOBAMA1/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A02.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A05.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A06.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A07.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A08.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A10.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A12.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A13.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A17.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A18.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A29.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A31.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A33.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM11/V01/T01/JSUS/000/A35.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/ATR503/A/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/ATR503/A/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/ATR503/A/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/ATR503/A/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/ATR503/A/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/ATR503/A/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/ATR503/A/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/ATR503/A/A20.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/ATR503/A/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/ATR503/A/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/ATR503/A/A25.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/ATR503/A/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/ATR503/A/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSPBOBAMA1/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSPBOBAMA1/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSPBOBAMA1/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSPBOBAMA1/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSPBOBAMA1/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A02.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A05.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A06.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A07.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A08.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A10.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A12.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A13.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A17.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A18.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A29.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A31.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A33.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM12/V01/T01/JSUS/000/A35.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/ATR503/A/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/ATR503/A/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/ATR503/A/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/ATR503/A/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/ATR503/A/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/ATR503/A/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/ATR503/A/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/ATR503/A/A20.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/ATR503/A/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/ATR503/A/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/ATR503/A/A25.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/ATR503/A/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/ATR503/A/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSPBOBAMA1/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSPBOBAMA1/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSPBOBAMA1/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSPBOBAMA1/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSPBOBAMA1/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A02.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A04.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A05.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A06.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A07.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A08.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A09.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A10.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A12.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A13.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A15.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A16.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A17.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A18.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A29.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A31.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A33.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/pre/EJM13/V01/T01/JSUS/000/A35.wav
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_f0.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_npow.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_sp_0_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_sp_46_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_sp_92_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_sp_138_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_sp_184_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_sp_230_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_sp_276_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_sp_322_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_sp_368_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_sp_414_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_sp_460_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_sp_506_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_sp_552_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_sp_598_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_sp_644_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_sp_690_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_sp_736_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_sp_782_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_sp_828_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_sp_874_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_sp_920_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_sp_966_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_ap_0_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_ap_46_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_ap_92_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_ap_138_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_ap_184_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_ap_230_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_ap_276_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_ap_322_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_ap_368_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_ap_414_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_ap_460_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_ap_506_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_ap_552_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_ap_598_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_ap_644_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_ap_690_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_ap_736_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_ap_782_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_ap_828_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_ap_874_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_ap_920_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_ap_966_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_mcep.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_mid_codeap.pickle'>

# %%
class GMMTrainer(object):
    """
    this class offers the training of GMM with several types of covariance matrix.
    
    Parameters
    ----------
    n_mix : int 
        the number of mixture components of the GMM
    n_iter : int
        the number of iteration for EM algorithm
    covtype : str
        the type of covariance matrix of the GMM
        'full': full-covariance matrix
    
    Attributes
    ---------
    param : 
        sklearn-based model parameters of the GMM
    """
    
    def __init__(self, n_mix=64, n_iter=100, covtype='full'):
        self.n_mix = n_mix
        self.n_iter = n_iter
        self.covtype = covtype
        
        self.param = sklearn.mixture.GaussianMixture(n_components=self.n_mix,
                                                     covariance_type=self.covtype,
                                                     max_iter=self.n_iter)
        
    def train(self, jnt):
        """
        fit GMM parameter from given joint feature vector
        
        Parametes
        ---------
        jnt : array, shape(`T`, `jnt.shape[0]`)
            joint feature vector of original and target feature vector consisting of static and delta components
        """
        
        if self.covtype == 'full':
            self.param.fit(jnt)
            
        return
    
class GMMConvertor(object):
    """
    this class offers the several conversion techniques such as Maximum Likelihood Parameter Generation (MLPG)
    and Minimum Mean Square Error (MMSE).
    
    Parametes
    ---------
    n_mix : int
        the number of mixture components of the GMM
    covtype : str
        the type of covariance matrix of the GMM
        'full': full-covariance matrix
    gmmmode : str
        the type of the GMM for opening
        `None` : Normal Joint Density - GMM (JD-GMM)
    
    Attributes
    ---------
    param : 
        sklearn-based model parameters of the GMM
    w : shape(`n_mix`)
        vector of mixture component weight of the GMM
    jmean : shape(`n_mix`, `jnt.shape[0]`)
        Array of joint mean vector of the GMM
    jcov : shape(`n_mix`, `jnt.shape[0]`, `jnt.shape[0]`)
        array of joint covariance matrix of the GMM
    """
    
    def __init__(self, n_mix=64, covtype='full', gmmmode=None):
        self.n_mix = n_mix
        self.covtype = covtype
        self.gmmmode = gmmmode
        
    def open_from_param(self, param):
        """
        open GMM from GMMTrainer
        
        Parameters
        ----------
        param : GMMTrainer
            GMMTrainer class
        """
        
        self.param = param
        self._deploy_parameters()
        
        return
    
    def convert(self, data, cvtype='mlpg'):
        """
        convert data based on conditional probability density function
        
        Parametes
        ---------
        data : array, shape(`T`, `dim`)
            original data will be converted
        cvtype : str
            type of conversion technique
            `mlpg` : maximum likelihood parameter generation
            
        Returns
        ----------
        odata : array, shape(`T`, `dim`)
            converted data
        """
        
        # estimate parameter sequence
        cseq, wseq, mseq, covseq = self._gmmmap(data)
        
        if cvtype == 'mlpg':
            odata = self._mlpg(mseq, covseq)
        else:
            raise ValueError('please choose conversion mode in `mlpg`.')
        
        return odata
    
    def _gmmmap(self, sddata):
        # paramete for sequencial data
        T, sddim = sddata.shape
        
        # estimate posterior sequence
        wseq = self.pX.predict_proba(sddata)
        
        # estimate mixture sequence
        cseq = np.argmax(wseq, axis=1)
        
        mseq = np.zeros((T, sddim))
        covseq = np.zeros((T, sddim, sddim))
        for t in range(T):
            # read maximum likelihood mixture component in frame t
            m = cseq[t]
            
            # conditional mean vector sequence
            mseq[t] = self.meanY[m] + self.A[m] @ (sddata[t] - self.meanX[m])
            
            # conditional covariance sequence
            covseq[t] = self.cond_cov_inv[m]
        
        return cseq, wseq, mseq, covseq
    
    def _mlpg(self, mseq, covseq):
        # parameter for sequencial data
        T, sddim = mseq.shape
        
        # prepare W
        W = construct_static_and_delta_matrix(T, sddim // 2)
        
        # prepare D
        D = get_diagonal_precision_matrix(T, sddim, covseq)
        
        # calculate W'D
        WD = W.T @ D
        
        # W'DW
        WDW = WD @ W
        
        # W'Dm
        WDM = WD @ mseq.flatten()
        
        # estimate y = (W'DW)^-1 * W'Dm
        odata = scipy.sparse.linalg.spsolve(WDW, WDM, use_umfpack=False).reshape(T, sddim // 2)
        
        return odata
    
    def _deploy_parameters(self):
        # read JD-GMM parameters from self.param
        self.W = self.param.weights_
        self.jmean = self.param.means_
        self.jcov = self.param.covariances_
        
        # devide GMM parameters into source and target parameters
        sddim = self.jmean.shape[1] // 2
        self.meanX = self.jmean[:, 0:sddim]
        self.meanY = self.jmean[:, sddim:]
        self.covXX = self.jcov[:, :sddim, :sddim]
        self.covXY = self.jcov[:, :sddim, sddim:]
        self.covYX = self.jcov[:, sddim:, :sddim]
        self.covYY = self.jcov[:, sddim:, sddim:]
        
        # change model parameter of GMM into that of gmmmode
        if self.gmmmode is None:
            pass
        else:
            raise ValueError('please choose GMM mode in [None]')
            
        # estimate parameters for conversion
        self._set_Ab()
        self._set_pX()
        
        return
    
    def _set_Ab(self):
        # calculate A and b from self.jmean, self.jcov
        sddim = self.jmean.shape[1] // 2
        
        # calculate inverse covariance for covariance XX in each mixture
        self.covXXinv = np.zeros((self.n_mix, sddim, sddim))
        for m in range(self.n_mix):
            self.covXXinv[m] = np.linalg.inv(self.covXX[m])
            
        # calculate A, b, and conditional covariance given X
        self.A = np.zeros((self.n_mix, sddim, sddim))
        self.b = np.zeros((self.n_mix, sddim))
        self.cond_cov_inv = np.zeros((self.n_mix, sddim, sddim))
        for m in range(self.n_mix):
            # calculate A (A = yxcov_m * xxcov_m^-1)
            self.A[m] = self.covYX[m] @ self.covXXinv[m]
            
            # calculate b (b = mean^Y - A * mean^X)
            self.b[m] = self.meanY[m] - self.A[m] @ self.meanX[m]
            
            # calculate conditional covariance (cov^(Y|X)^-1 = (yycov - A * xycov)^-1)
            self.cond_cov_inv[m] = np.linalg.inv(self.covYY[m] - self.A[m] @ self.covXY[m])
            
        return
    
    def _set_pX(self):
        # probability density function of X 
        self.pX = sklearn.mixture.GaussianMixture(n_components=self.n_mix, covariance_type=self.covtype)
        self.pX.weights_ = self.W
        self.pX.means_ = self.meanX
        self.pX.covariances_ = self.covXX
        
        # following function is required to estimate porsterior
        # p(x | \lambda^(X))
        self.pX.precisions_cholesky_ = _compute_precision_cholesky(self.covXX, self.covtype)
        
        return
    
def get_diagonal_precision_matrix(T, D, covseq):
    return scipy.sparse.block_diag(covseq, format='csr')

# %%
def get_alignment(odata, onpow, tdata, tnpow, opow=-20, tpow=-20, sd=0, cvdata=None, given_twf=None, otflag=None, distance='melcd'):
    """
    get alignment between original and target.
    
    Parameters
    ----------
    odata : array, shape(`T`, `dim`)
        acoustic feature vector of original
    onpow : array, shape(`T`)
        Normalized power vector of original
    tdata : array, shape(`T`, `dim`)
        acoustic feature vector of target
    tnpow : array, shape(`T`)
        Normalized power vector of target
    opow : float
        power threshold of original
    tpow : float
        power threshold of target
    sd : int
        start dimension to be used for alignment
    cvdata : array, shape(`T`, `dim`)
        converted original data
    given_twf : array, shape(`T_new`, `dim * 2`)
        Alignment given twf
    otflag : str
        Alignment into the length of specification
        'org' : alignment into original length
        'tar' : alignment into target length
    distance : str
        Distance function to be used
    
    Returns
    ----------
    jdata : array, shape(`T_new`, `dim * 2`)
        joint static and delta feature vector
    twf : array, shape(`T_new`, `dim * 2`)
        Time warping function
    mcd : float
        Mel-cepstrum distortion between arrays
    """
    
    oexdata = extsddata(odata[:, sd:], onpow, power_threshold=opow)
    texdata = extsddata(tdata[:, sd:], tnpow, power_threshold=tpow)
    
    if cvdata is None:
        align_odata = oexdata
    else:
        cvexdata = extsddata(cvdata, onpow, power_threshold=opow)
        align_odata = cvexdata
    
    if given_twf is None: 
        twf = estimate_twf(align_odata, texdata, distance=distance, otflag=otflag)
    else:
        twf = given_twf
    
    jdata = align_data(oexdata, texdata, twf)
    mcd = melcd(align_odata[twf[0]], texdata[twf[1]])
    
    return jdata, twf, mcd

def align_feature_vectors(odata, onpows, tdata, tnpows, opow=-100, tpow=-100, itnum=3, sd=0, given_twfs=None, otflag=None):
    """
    get alignment to create joint feature vector
    
    Parameters
    ----------
    odata : list, (`num_files`)
        List of original feature vectors
    onpow : list, (`num_files`)
        List of original npows
    tdata : list, (`num_files`)
        List of target feature vectors
    tnpow : list, (`num_files`)
        List of target npows
    opow : float
        power threshold of original
    tpow : float
        power threshold of target
    itnum : int
        the number of iteration
    sd : int
        start dimension of feature vector to be used for alignment
    given_twf : array, shape(`T_new`, `dim * 2`)
        use given alignment while 1st iteration
    otflag : str
        Alignment into the length of specification
        'org' : alignment into original length
        'tar' : alignment into target length
    distance : str
        Distance function to be used
    
    Returns
    ----------
    jdata : array, shape(`T_new`, `dim * 2`)
        joint static and delta feature vector
    twf : array, shape(`T_new`, `dim * 2`)
        Time warping function
    mcd : float
        Mel-cepstrum distortion between arrays
    """
    
    it = 1
    num_files = len(odata)
    cvgmm, cvdata = None, None
    for it in range(1, itnum+1):
        print('{}-th joint feature extraction starts.'.format(it))
        
        # alignment
        twfs, jfvs = [], []
        for i in range(num_files):
            if it == 1 and given_twfs is not None:
                gtwf = given_twfs[i]
            else:
                gtwf = None
            
            if it > 1:
                cvdata = cvgmm.convert(static_delta(odata[i][:, sd:]))
            
            jdata, twf, mcd = get_alignment(odata[i], onpows[i], tdata[i], tnpows[i], opow=opow, tpow=tpow,
                                            sd=sd, cvdata=cvdata, given_twf=gtwf, otflag=otflag)
            twfs.append(twf)
            jfvs.append(jdata)
            print('distortion [dB] for {}-th file: {}'.format(i+1, mcd))
            
        jnt_data = transform_jnt(jfvs)
        
        if it != itnum:
            # train GMM, if not final iteration
            datagmm = GMMTrainer()
            datagmm.train(jnt_data)
            cvgmm = GMMConvertor()
            cvgmm.open_from_param(datagmm.param)
        it += 1
    return jfvs, twfs

# %%
# 2. estimate twf and jnt

for i in range(0, len(mid_mceplist), len(org_mceplist)):
    org_mceps = org_mceplist
    org_npows = org_npowlist
    mid_mceps = mid_mceplist[i:i+len(org_mceps)]
    mid_npows = mid_npowlist[i:i+len(org_npows)]
    assert len(org_mceps) == len(mid_mceps)
    assert len(org_npows) == len(mid_npows)
    assert len(org_mceps) == len(org_npows)
    
    # dtw between original and target 0-th and silence
    print("## alignment mcep 0-th and silence ##")
    jmceps, twfs = align_feature_vectors(org_mceps, org_npows, mid_mceps, mid_npows, opow=-100, tpow=-100, sd=1)
    jnt_mcep = transform_jnt(jmceps)
    
    # create joint feature for codeap using given twfs
    print("## alignment codeap into target length using given twfs ##")
    org_codeaps = org_codeaplist
    mid_codeaps = mid_codeaplist[i:i+len(org_codeaplist)]
    jcodeaps = []
    
    for j in range(len(org_codeaps)):
        # extract codeap joint feature vector
        jcodeap, _, _ = get_alignment(org_codeaps[j], org_npows[j], mid_codeaps[j], mid_npows[j], opow=-100, tpow=-100, given_twf=twfs[j])
        jcodeaps.append(jcodeap)
        
    jnt_codeap = transform_jnt(jcodeaps)
    
    # save joint feature vectors
    with open(output_path + "_jnt_mcep_{}_.pickle".format(i), 'wb') as f:   
        print(f)
        pickle.dump(jnt_mcep, f)
    with open(output_path + "_jnt_codeap_{}_.pickle".format(i), 'wb') as f:   
        print(f)
        pickle.dump(jnt_codeap, f)
# Out:
# ## alignment mcep 0-th and silence ##
# 1-th joint feature extraction starts.
# distortion [dB] for 1-th file: 8.431588013739177
# distortion [dB] for 2-th file: 7.913750814914016
# distortion [dB] for 3-th file: 8.19214300036931
# distortion [dB] for 4-th file: 8.381481176573248
# distortion [dB] for 5-th file: 8.18031970947171
# distortion [dB] for 6-th file: 7.83388329363048
# distortion [dB] for 7-th file: 7.932083014105352
# distortion [dB] for 8-th file: 7.519831319170946
# distortion [dB] for 9-th file: 7.7475795848193645
# distortion [dB] for 10-th file: 8.132770564327584
# distortion [dB] for 11-th file: 7.706596954874411
# distortion [dB] for 12-th file: 8.705937547103662
# distortion [dB] for 13-th file: 7.695411830732085
# distortion [dB] for 14-th file: 7.985844495549979
# distortion [dB] for 15-th file: 8.68081682822592
# distortion [dB] for 16-th file: 8.294458537683395
# distortion [dB] for 17-th file: 8.661478522707672
# distortion [dB] for 18-th file: 8.28539664971344
# distortion [dB] for 19-th file: 8.56536369516244
# distortion [dB] for 20-th file: 7.844924100041393
# distortion [dB] for 21-th file: 7.879265539508793
# distortion [dB] for 22-th file: 8.422620220052936
# distortion [dB] for 23-th file: 7.788064140083957
# distortion [dB] for 24-th file: 7.869981823479507
# distortion [dB] for 25-th file: 10.182088724978986
# distortion [dB] for 26-th file: 7.562056185824451
# distortion [dB] for 27-th file: 7.910773810737603
# distortion [dB] for 28-th file: 8.04902914221973
# distortion [dB] for 29-th file: 8.38072057541527
# distortion [dB] for 30-th file: 8.246492386859256
# distortion [dB] for 31-th file: 7.940035172770811
# distortion [dB] for 32-th file: 8.218471132176006
# distortion [dB] for 33-th file: 8.239325429370838
# distortion [dB] for 34-th file: 8.324162162950472
# distortion [dB] for 35-th file: 7.797377105495797
# distortion [dB] for 36-th file: 7.991055602097045
# distortion [dB] for 37-th file: 7.658367937900495
# distortion [dB] for 38-th file: 7.94597639260842
# distortion [dB] for 39-th file: 7.642783802437758
# distortion [dB] for 40-th file: 8.038764922945788
# distortion [dB] for 41-th file: 8.229626759003004
# distortion [dB] for 42-th file: 7.9350794118759405
# distortion [dB] for 43-th file: 8.29112059396062
# distortion [dB] for 44-th file: 7.3954919727555355
# distortion [dB] for 45-th file: 7.341383562073222
# distortion [dB] for 46-th file: 8.714999442932832
# 2-th joint feature extraction starts.
# distortion [dB] for 1-th file: 7.719460867317847
# distortion [dB] for 2-th file: 7.776996473417055
# distortion [dB] for 3-th file: 7.67701417709956
# distortion [dB] for 4-th file: 8.354837106382687
# distortion [dB] for 5-th file: 8.622840131046072
# distortion [dB] for 6-th file: 7.778509068994976
# distortion [dB] for 7-th file: 8.13688884904049
# distortion [dB] for 8-th file: 8.60294393863529
# distortion [dB] for 9-th file: 7.759047355863598
# distortion [dB] for 10-th file: 8.206657658028945
# distortion [dB] for 11-th file: 7.895969398971161
# distortion [dB] for 12-th file: 7.884963910363907
# distortion [dB] for 13-th file: 7.518360039609186
# distortion [dB] for 14-th file: 7.847107894581641
# distortion [dB] for 15-th file: 8.540854592183361
# distortion [dB] for 16-th file: 8.196203584368083
# distortion [dB] for 17-th file: 8.194384301687984
# distortion [dB] for 18-th file: 8.325899371508873
# distortion [dB] for 19-th file: 8.69976213240537
# distortion [dB] for 20-th file: 8.151245318141818
# distortion [dB] for 21-th file: 9.331440506550388
# distortion [dB] for 22-th file: 8.296202679414264
# distortion [dB] for 23-th file: 8.439966059681044
# distortion [dB] for 24-th file: 8.247888648322677
# distortion [dB] for 25-th file: 8.958969379789885
# distortion [dB] for 26-th file: 7.885808992839003
# distortion [dB] for 27-th file: 8.356374342720883
# distortion [dB] for 28-th file: 8.238502114404687
# distortion [dB] for 29-th file: 7.8332328554617074
# distortion [dB] for 30-th file: 9.167637481008477
# distortion [dB] for 31-th file: 8.547749240670909
# distortion [dB] for 32-th file: 8.242686226130607
# distortion [dB] for 33-th file: 8.089442689339764
# distortion [dB] for 34-th file: 8.011404904609035
# distortion [dB] for 35-th file: 7.538781396054098
# distortion [dB] for 36-th file: 8.209332996198768
# distortion [dB] for 37-th file: 8.6685910011443
# distortion [dB] for 38-th file: 8.3689250505644
# distortion [dB] for 39-th file: 9.471368735410264
# distortion [dB] for 40-th file: 7.931934583467454
# distortion [dB] for 41-th file: 8.530860082309273
# distortion [dB] for 42-th file: 7.974247685403503
# distortion [dB] for 43-th file: 8.052471296687614
# distortion [dB] for 44-th file: 8.829010712576673
# distortion [dB] for 45-th file: 7.659133739558271
# distortion [dB] for 46-th file: 7.986988070387021
# 3-th joint feature extraction starts.
# distortion [dB] for 1-th file: 7.978608173430082
# distortion [dB] for 2-th file: 7.853151173711912
# distortion [dB] for 3-th file: 8.315922081133595
# distortion [dB] for 4-th file: 7.939954829159049
# distortion [dB] for 5-th file: 8.790621760814677
# distortion [dB] for 6-th file: 7.673022849581214
# distortion [dB] for 7-th file: 7.98966457777207
# distortion [dB] for 8-th file: 8.51816363798277
# distortion [dB] for 9-th file: 7.91725745982095
# distortion [dB] for 10-th file: 8.410760267668316
# distortion [dB] for 11-th file: 8.431157038659826
# distortion [dB] for 12-th file: 7.320904906968578
# distortion [dB] for 13-th file: 7.77435268300676
# distortion [dB] for 14-th file: 7.832582640968474
# distortion [dB] for 15-th file: 8.796647587616425
# distortion [dB] for 16-th file: 8.484277450610742
# distortion [dB] for 17-th file: 8.01219857341528
# distortion [dB] for 18-th file: 7.5546976622649735
# distortion [dB] for 19-th file: 7.541549493069574
# distortion [dB] for 20-th file: 7.886722614587854
# distortion [dB] for 21-th file: 9.437049675073341
# distortion [dB] for 22-th file: 8.768198583688964
# distortion [dB] for 23-th file: 7.936302810409647
# distortion [dB] for 24-th file: 7.752393612378941
# distortion [dB] for 25-th file: 8.26583685883552
# distortion [dB] for 26-th file: 8.086043417624765
# distortion [dB] for 27-th file: 8.569081033298527
# distortion [dB] for 28-th file: 7.922369916013953
# distortion [dB] for 29-th file: 7.962816241045753
# distortion [dB] for 30-th file: 8.806850257006516
# distortion [dB] for 31-th file: 9.032699803360927
# distortion [dB] for 32-th file: 8.068590801248074
# distortion [dB] for 33-th file: 8.345840301655812
# distortion [dB] for 34-th file: 8.158049789191926
# distortion [dB] for 35-th file: 7.580615777418437
# distortion [dB] for 36-th file: 7.900728358228988
# distortion [dB] for 37-th file: 7.759853475883977
# distortion [dB] for 38-th file: 7.843347572511308
# distortion [dB] for 39-th file: 8.47227752383864
# distortion [dB] for 40-th file: 7.656501795727967
# distortion [dB] for 41-th file: 8.137946573932055
# distortion [dB] for 42-th file: 8.735252920474897
# distortion [dB] for 43-th file: 8.685655840041033
# distortion [dB] for 44-th file: 8.06552809956808
# distortion [dB] for 45-th file: 7.6494792112976056
# distortion [dB] for 46-th file: 7.793032829736455
# ## alignment codeap into target length using given twfs ##
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_jnt_mcep_0_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_jnt_codeap_0_.pickle'>
# ## alignment mcep 0-th and silence ##
# 1-th joint feature extraction starts.
# distortion [dB] for 1-th file: 8.816272052399077
# distortion [dB] for 2-th file: 10.717767407533865
# distortion [dB] for 3-th file: 9.075235841475921
# distortion [dB] for 4-th file: 8.883369707039325
# distortion [dB] for 5-th file: 9.321117627157058
# distortion [dB] for 6-th file: 8.425421559862542
# distortion [dB] for 7-th file: 10.12453893865825
# distortion [dB] for 8-th file: 8.904599482762476
# distortion [dB] for 9-th file: 8.274082397917779
# distortion [dB] for 10-th file: 9.664603608626518
# distortion [dB] for 11-th file: 9.02563387907011
# distortion [dB] for 12-th file: 9.270009732055419
# distortion [dB] for 13-th file: 9.032982120997499
# distortion [dB] for 14-th file: 8.763448994852826
# distortion [dB] for 15-th file: 8.27163803386972
# distortion [dB] for 16-th file: 8.654440787421303
# distortion [dB] for 17-th file: 9.502305270235302
# distortion [dB] for 18-th file: 9.574442066616834
# distortion [dB] for 19-th file: 9.098494201956008
# distortion [dB] for 20-th file: 9.00685006256592
# distortion [dB] for 21-th file: 8.995986423772349
# distortion [dB] for 22-th file: 9.959295929129823
# distortion [dB] for 23-th file: 9.328600474523714
# distortion [dB] for 24-th file: 8.5761696101854
# distortion [dB] for 25-th file: 9.411327044269632
# distortion [dB] for 26-th file: 7.998876381309792
# distortion [dB] for 27-th file: 8.016912735769155
# distortion [dB] for 28-th file: 8.88419263190642
# distortion [dB] for 29-th file: 9.302033621384968
# distortion [dB] for 30-th file: 8.588622889587777
# distortion [dB] for 31-th file: 9.062491747075102
# distortion [dB] for 32-th file: 9.56920150694574
# distortion [dB] for 33-th file: 9.032221231329165
# distortion [dB] for 34-th file: 10.516681249274079
# distortion [dB] for 35-th file: 9.912387181466098
# distortion [dB] for 36-th file: 8.450945936341222
# distortion [dB] for 37-th file: 9.546311355728632
# distortion [dB] for 38-th file: 8.547656160665161
# distortion [dB] for 39-th file: 9.130866600459424
# distortion [dB] for 40-th file: 8.523693878842183
# distortion [dB] for 41-th file: 10.436245343664831
# distortion [dB] for 42-th file: 8.52656798494743
# distortion [dB] for 43-th file: 8.767640136360473
# distortion [dB] for 44-th file: 8.396896641007201
# distortion [dB] for 45-th file: 9.95767490401518
# distortion [dB] for 46-th file: 8.916919464452018
# 2-th joint feature extraction starts.
# distortion [dB] for 1-th file: 8.88938674460377
# distortion [dB] for 2-th file: 10.497172231417112
# distortion [dB] for 3-th file: 9.799877603341576
# distortion [dB] for 4-th file: 9.173825175324833
# distortion [dB] for 5-th file: 9.04482180457756
# distortion [dB] for 6-th file: 9.111025571131476
# distortion [dB] for 7-th file: 9.431173645584906
# distortion [dB] for 8-th file: 9.84553761724836
# distortion [dB] for 9-th file: 9.451631633763515
# distortion [dB] for 10-th file: 9.793670277068482
# distortion [dB] for 11-th file: 9.180814427005007
# distortion [dB] for 12-th file: 9.288675591070405
# distortion [dB] for 13-th file: 9.067376468859353
# distortion [dB] for 14-th file: 8.687322367761121
# distortion [dB] for 15-th file: 9.573659842606316
# distortion [dB] for 16-th file: 8.20479246409051
# distortion [dB] for 17-th file: 9.286952337247488
# distortion [dB] for 18-th file: 9.414045986280083
# distortion [dB] for 19-th file: 8.73859290636633
# distortion [dB] for 20-th file: 9.676071621684661
# distortion [dB] for 21-th file: 9.626021409440286
# distortion [dB] for 22-th file: 8.728436866704264
# distortion [dB] for 23-th file: 9.262347140786774
# distortion [dB] for 24-th file: 9.024033128374407
# distortion [dB] for 25-th file: 9.014938011162249
# distortion [dB] for 26-th file: 8.582286769803154
# distortion [dB] for 27-th file: 8.565766075149083
# distortion [dB] for 28-th file: 9.70908007616777
# distortion [dB] for 29-th file: 9.380354408692154
# distortion [dB] for 30-th file: 9.082726675877158
# distortion [dB] for 31-th file: 9.081394283724295
# distortion [dB] for 32-th file: 9.056491439715785
# distortion [dB] for 33-th file: 9.18755021705567
# distortion [dB] for 34-th file: 9.711296631170587
# distortion [dB] for 35-th file: 8.91000883876066
# distortion [dB] for 36-th file: 9.29834814151961
# distortion [dB] for 37-th file: 8.51566965689265
# distortion [dB] for 38-th file: 7.772494754071905
# distortion [dB] for 39-th file: 9.421719152007315
# distortion [dB] for 40-th file: 10.168009063452402
# distortion [dB] for 41-th file: 9.619137102314996
# distortion [dB] for 42-th file: 8.828305542605571
# distortion [dB] for 43-th file: 8.946040768494994
# distortion [dB] for 44-th file: 9.240875322423745
# distortion [dB] for 45-th file: 9.85452262306638
# distortion [dB] for 46-th file: 9.836870191967467
# 3-th joint feature extraction starts.
# distortion [dB] for 1-th file: 8.787534031948399
# distortion [dB] for 2-th file: 9.719635202905685
# distortion [dB] for 3-th file: 9.711736509613804
# distortion [dB] for 4-th file: 9.447690465419392
# distortion [dB] for 5-th file: 9.616244714906752
# distortion [dB] for 6-th file: 9.177928421662367
# distortion [dB] for 7-th file: 9.763315379838021
# distortion [dB] for 8-th file: 9.614552315103548
# distortion [dB] for 9-th file: 9.301814893735084
# distortion [dB] for 10-th file: 9.350301548447586
# distortion [dB] for 11-th file: 9.155005803585782
# distortion [dB] for 12-th file: 9.080351489652996
# distortion [dB] for 13-th file: 9.705488910563744
# distortion [dB] for 14-th file: 8.697573405537163
# distortion [dB] for 15-th file: 9.617876807083892
# distortion [dB] for 16-th file: 8.392584925825961
# distortion [dB] for 17-th file: 9.00462625093608
# distortion [dB] for 18-th file: 9.45860610931462
# distortion [dB] for 19-th file: 8.943928708999485
# distortion [dB] for 20-th file: 9.706708497458976
# distortion [dB] for 21-th file: 9.434006385667868
# distortion [dB] for 22-th file: 8.86719433951693
# distortion [dB] for 23-th file: 8.799564453363269
# distortion [dB] for 24-th file: 9.013312606302698
# distortion [dB] for 25-th file: 9.97906035384571
# distortion [dB] for 26-th file: 8.225513698799848
# distortion [dB] for 27-th file: 7.8137380201617415
# distortion [dB] for 28-th file: 9.335066911830069
# distortion [dB] for 29-th file: 8.869841446639228
# distortion [dB] for 30-th file: 9.038532523408644
# distortion [dB] for 31-th file: 8.994833710446692
# distortion [dB] for 32-th file: 9.018608421027405
# distortion [dB] for 33-th file: 8.94281595378178
# distortion [dB] for 34-th file: 9.81669853617997
# distortion [dB] for 35-th file: 9.126625492208381
# distortion [dB] for 36-th file: 9.110745836605814
# distortion [dB] for 37-th file: 8.428500181490595
# distortion [dB] for 38-th file: 8.433690466921348
# distortion [dB] for 39-th file: 8.99873052434368
# distortion [dB] for 40-th file: 9.71738552014485
# distortion [dB] for 41-th file: 9.336155750595951
# distortion [dB] for 42-th file: 9.327224808516053
# distortion [dB] for 43-th file: 8.236140885727197
# distortion [dB] for 44-th file: 9.03078055727262
# distortion [dB] for 45-th file: 9.664917285123801
# distortion [dB] for 46-th file: 9.271016699283159
# ## alignment codeap into target length using given twfs ##
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_jnt_mcep_46_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_jnt_codeap_46_.pickle'>
# ## alignment mcep 0-th and silence ##
# 1-th joint feature extraction starts.
# distortion [dB] for 1-th file: 8.306143381370196
# distortion [dB] for 2-th file: 8.008114068228837
# distortion [dB] for 3-th file: 8.487771487376579
# distortion [dB] for 4-th file: 7.991756999552558
# distortion [dB] for 5-th file: 8.794182452918236
# distortion [dB] for 6-th file: 7.712738889626431
# distortion [dB] for 7-th file: 8.252989642068806
# distortion [dB] for 8-th file: 8.052697080541003
# distortion [dB] for 9-th file: 8.230270712545016
# distortion [dB] for 10-th file: 8.394361299023696
# distortion [dB] for 11-th file: 9.006570164889567
# distortion [dB] for 12-th file: 8.240613331685779
# distortion [dB] for 13-th file: 7.8465739114107125
# distortion [dB] for 14-th file: 8.014901460482472
# distortion [dB] for 15-th file: 7.926318185109187
# distortion [dB] for 16-th file: 8.227613135149854
# distortion [dB] for 17-th file: 7.568234528712476
# distortion [dB] for 18-th file: 8.663353006315646
# distortion [dB] for 19-th file: 8.908187552214919
# distortion [dB] for 20-th file: 9.778546553339895
# distortion [dB] for 21-th file: 8.760818403685137
# distortion [dB] for 22-th file: 8.715933055187376
# distortion [dB] for 23-th file: 8.827288498624547
# distortion [dB] for 24-th file: 7.969296429908798
# distortion [dB] for 25-th file: 9.37839881223984
# distortion [dB] for 26-th file: 7.81711181664739
# distortion [dB] for 27-th file: 8.254136511681246
# distortion [dB] for 28-th file: 8.048634727246421
# distortion [dB] for 29-th file: 8.581230520070973
# distortion [dB] for 30-th file: 8.708154435432867
# distortion [dB] for 31-th file: 8.507435901489574
# distortion [dB] for 32-th file: 8.836620840421586
# distortion [dB] for 33-th file: 8.739873186055974
# distortion [dB] for 34-th file: 8.646013809026872
# distortion [dB] for 35-th file: 7.925902082918676
# distortion [dB] for 36-th file: 7.853757690944911
# distortion [dB] for 37-th file: 8.164421817028346
# distortion [dB] for 38-th file: 8.02432793262659
# distortion [dB] for 39-th file: 7.559832481589253
# distortion [dB] for 40-th file: 7.791302489588951
# distortion [dB] for 41-th file: 8.818117927041623
# distortion [dB] for 42-th file: 7.607228032686734
# distortion [dB] for 43-th file: 8.285104061221283
# distortion [dB] for 44-th file: 7.430222914194103
# distortion [dB] for 45-th file: 7.776421332245199
# distortion [dB] for 46-th file: 9.312428484802693
# 2-th joint feature extraction starts.
# distortion [dB] for 1-th file: 8.584583566374947
# distortion [dB] for 2-th file: 8.637998040933857
# distortion [dB] for 3-th file: 8.49523338653868
# distortion [dB] for 4-th file: 8.852720891412895
# distortion [dB] for 5-th file: 8.94202321936197
# distortion [dB] for 6-th file: 8.333651562116799
# distortion [dB] for 7-th file: 8.978289732197883
# distortion [dB] for 8-th file: 9.096236008639048
# distortion [dB] for 9-th file: 8.58078721986738
# distortion [dB] for 10-th file: 9.485419257518968
# distortion [dB] for 11-th file: 8.72221861219826
# distortion [dB] for 12-th file: 7.773427581032789
# distortion [dB] for 13-th file: 8.651332398913095
# distortion [dB] for 14-th file: 8.150013229760658
# distortion [dB] for 15-th file: 9.426198967670938
# distortion [dB] for 16-th file: 7.709725869135706
# distortion [dB] for 17-th file: 7.4182866757135075
# distortion [dB] for 18-th file: 8.9118748988269
# distortion [dB] for 19-th file: 8.812062266290322
# distortion [dB] for 20-th file: 8.519083746270784
# distortion [dB] for 21-th file: 9.156664575970963
# distortion [dB] for 22-th file: 8.563798134315094
# distortion [dB] for 23-th file: 8.76823266221024
# distortion [dB] for 24-th file: 8.725246321802786
# distortion [dB] for 25-th file: 8.878896015527001
# distortion [dB] for 26-th file: 8.902197498533692
# distortion [dB] for 27-th file: 8.843688984815081
# distortion [dB] for 28-th file: 8.801955442840349
# distortion [dB] for 29-th file: 8.791620541543237
# distortion [dB] for 30-th file: 9.233389994452038
# distortion [dB] for 31-th file: 8.925704884106933
# distortion [dB] for 32-th file: 8.696565589459995
# distortion [dB] for 33-th file: 8.419749934216393
# distortion [dB] for 34-th file: 8.949339756721598
# distortion [dB] for 35-th file: 8.66422814449052
# distortion [dB] for 36-th file: 8.639319064274567
# distortion [dB] for 37-th file: 8.628358553007422
# distortion [dB] for 38-th file: 8.324244026130783
# distortion [dB] for 39-th file: 8.731650969069555
# distortion [dB] for 40-th file: 8.765172037638328
# distortion [dB] for 41-th file: 9.234559746189081
# distortion [dB] for 42-th file: 8.640688132056324
# distortion [dB] for 43-th file: 8.640508537826422
# distortion [dB] for 44-th file: 9.015184692668077
# distortion [dB] for 45-th file: 8.20218452432368
# distortion [dB] for 46-th file: 8.803676245459783
# 3-th joint feature extraction starts.
# distortion [dB] for 1-th file: 8.993487255312468
# distortion [dB] for 2-th file: 9.386219152337848
# distortion [dB] for 3-th file: 8.626409175717146
# distortion [dB] for 4-th file: 9.031342347369838
# distortion [dB] for 5-th file: 8.733221061008631
# distortion [dB] for 6-th file: 8.382497577738198
# distortion [dB] for 7-th file: 9.644646824476554
# distortion [dB] for 8-th file: 9.360206856676115
# distortion [dB] for 9-th file: 8.835682546313105
# distortion [dB] for 10-th file: 10.169578126511285
# distortion [dB] for 11-th file: 8.664457595417474
# distortion [dB] for 12-th file: 8.049701660881219
# distortion [dB] for 13-th file: 9.109774037757603
# distortion [dB] for 14-th file: 8.517684404242871
# distortion [dB] for 15-th file: 9.070225176645572
# distortion [dB] for 16-th file: 7.704776571898736
# distortion [dB] for 17-th file: 7.906803604278214
# distortion [dB] for 18-th file: 8.697849054209458
# distortion [dB] for 19-th file: 8.826819276370847
# distortion [dB] for 20-th file: 8.237036949172525
# distortion [dB] for 21-th file: 9.538145699294745
# distortion [dB] for 22-th file: 9.007301957656187
# distortion [dB] for 23-th file: 8.804106708330753
# distortion [dB] for 24-th file: 9.907239229030482
# distortion [dB] for 25-th file: 9.196339033084111
# distortion [dB] for 26-th file: 9.069523397323865
# distortion [dB] for 27-th file: 8.438975845365103
# distortion [dB] for 28-th file: 8.907528983088932
# distortion [dB] for 29-th file: 8.534383187220051
# distortion [dB] for 30-th file: 8.924509215052224
# distortion [dB] for 31-th file: 9.486763818689202
# distortion [dB] for 32-th file: 9.321474660063593
# distortion [dB] for 33-th file: 8.386652068719684
# distortion [dB] for 34-th file: 8.7574443026442
# distortion [dB] for 35-th file: 8.949326587919314
# distortion [dB] for 36-th file: 8.890978030198553
# distortion [dB] for 37-th file: 8.821947556458241
# distortion [dB] for 38-th file: 8.230871083948797
# distortion [dB] for 39-th file: 8.62444724601842
# distortion [dB] for 40-th file: 8.617640090604528
# distortion [dB] for 41-th file: 9.595095800636663
# distortion [dB] for 42-th file: 7.955577017291929
# distortion [dB] for 43-th file: 9.08929935685461
# distortion [dB] for 44-th file: 9.216835839510056
# distortion [dB] for 45-th file: 8.555973986337253
# distortion [dB] for 46-th file: 8.923637637817574
# ## alignment codeap into target length using given twfs ##
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_jnt_mcep_92_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_jnt_codeap_92_.pickle'>
# ## alignment mcep 0-th and silence ##
# 1-th joint feature extraction starts.
# distortion [dB] for 1-th file: 7.826489557077148
# distortion [dB] for 2-th file: 7.3964657287268665
# distortion [dB] for 3-th file: 8.28893093141385
# distortion [dB] for 4-th file: 8.004866490113658
# distortion [dB] for 5-th file: 7.713795579492532
# distortion [dB] for 6-th file: 7.535541579327784
# distortion [dB] for 7-th file: 8.147226791532406
# distortion [dB] for 8-th file: 7.8026478669301005
# distortion [dB] for 9-th file: 7.782085181243708
# distortion [dB] for 10-th file: 7.698062133182503
# distortion [dB] for 11-th file: 7.958079391580381
# distortion [dB] for 12-th file: 7.714321978295984
# distortion [dB] for 13-th file: 7.801083685659621
# distortion [dB] for 14-th file: 8.043250561471583
# distortion [dB] for 15-th file: 7.269315857559734
# distortion [dB] for 16-th file: 7.8905928851179565
# distortion [dB] for 17-th file: 7.476681189094822
# distortion [dB] for 18-th file: 8.506071289164826
# distortion [dB] for 19-th file: 8.0613889517003
# distortion [dB] for 20-th file: 7.6839811827476625
# distortion [dB] for 21-th file: 8.022431914635328
# distortion [dB] for 22-th file: 7.591510449930504
# distortion [dB] for 23-th file: 7.512300346024725
# distortion [dB] for 24-th file: 7.415589211209837
# distortion [dB] for 25-th file: 7.764192945649501
# distortion [dB] for 26-th file: 7.404374842007916
# distortion [dB] for 27-th file: 7.5787690377018455
# distortion [dB] for 28-th file: 8.16927697852511
# distortion [dB] for 29-th file: 8.569723078148295
# distortion [dB] for 30-th file: 7.742840098773376
# distortion [dB] for 31-th file: 7.739361938455346
# distortion [dB] for 32-th file: 7.901761747530873
# distortion [dB] for 33-th file: 7.755923649324692
# distortion [dB] for 34-th file: 8.075788441474426
# distortion [dB] for 35-th file: 8.413699301962245
# distortion [dB] for 36-th file: 7.807191215635267
# distortion [dB] for 37-th file: 7.551057030043755
# distortion [dB] for 38-th file: 7.1316963334439185
# distortion [dB] for 39-th file: 7.384729089584302
# distortion [dB] for 40-th file: 7.831946483753089
# distortion [dB] for 41-th file: 8.262714472475933
# distortion [dB] for 42-th file: 7.506244659625195
# distortion [dB] for 43-th file: 8.11911092581655
# distortion [dB] for 44-th file: 7.573591813913256
# distortion [dB] for 45-th file: 7.162837538024019
# distortion [dB] for 46-th file: 8.215222477641676
# 2-th joint feature extraction starts.
# distortion [dB] for 1-th file: 9.327006886935852
# distortion [dB] for 2-th file: 8.522729822444878
# distortion [dB] for 3-th file: 9.5253547070408
# distortion [dB] for 4-th file: 9.216913725331754
# distortion [dB] for 5-th file: 11.22937195364667
# distortion [dB] for 6-th file: 10.068501198313385
# distortion [dB] for 7-th file: 9.38080556305373
# distortion [dB] for 8-th file: 10.294788577058718
# distortion [dB] for 9-th file: 9.024873357978821
# distortion [dB] for 10-th file: 9.67469113476069
# distortion [dB] for 11-th file: 10.327063342476222
# distortion [dB] for 12-th file: 8.70591029980068
# distortion [dB] for 13-th file: 9.729024063011206
# distortion [dB] for 14-th file: 8.39147820158856
# distortion [dB] for 15-th file: 9.290625652704229
# distortion [dB] for 16-th file: 9.146701704448857
# distortion [dB] for 17-th file: 10.022505463455255
# distortion [dB] for 18-th file: 8.084257605669038
# distortion [dB] for 19-th file: 9.992471148532571
# distortion [dB] for 20-th file: 7.856262895237222
# distortion [dB] for 21-th file: 10.879860030252082
# distortion [dB] for 22-th file: 8.706710142253016
# distortion [dB] for 23-th file: 9.689420856614698
# distortion [dB] for 24-th file: 8.33143123336466
# distortion [dB] for 25-th file: 9.999980613485754
# distortion [dB] for 26-th file: 8.575064669564332
# distortion [dB] for 27-th file: 10.468388701087028
# distortion [dB] for 28-th file: 9.660518784167792
# distortion [dB] for 29-th file: 10.311674667827155
# distortion [dB] for 30-th file: 10.186187317855705
# distortion [dB] for 31-th file: 10.031635194987894
# distortion [dB] for 32-th file: 10.0328407177149
# distortion [dB] for 33-th file: 9.728189549853976
# distortion [dB] for 34-th file: 10.581819811468641
# distortion [dB] for 35-th file: 8.670627932751156
# distortion [dB] for 36-th file: 7.729239274104339
# distortion [dB] for 37-th file: 10.20421737043069
# distortion [dB] for 38-th file: 9.378252053793474
# distortion [dB] for 39-th file: 8.863792520615972
# distortion [dB] for 40-th file: 9.881333998746358
# distortion [dB] for 41-th file: 8.353430978893089
# distortion [dB] for 42-th file: 9.233581035808323
# distortion [dB] for 43-th file: 7.91732602532913
# distortion [dB] for 44-th file: 9.058260795719397
# distortion [dB] for 45-th file: 8.882189370496164
# distortion [dB] for 46-th file: 8.078277261671987
# 3-th joint feature extraction starts.
# distortion [dB] for 1-th file: 8.649077091591447
# distortion [dB] for 2-th file: 8.866494098283523
# distortion [dB] for 3-th file: 9.442833161747206
# distortion [dB] for 4-th file: 10.00233467832981
# distortion [dB] for 5-th file: 8.434620091397402
# distortion [dB] for 6-th file: 8.36666210846768
# distortion [dB] for 7-th file: 9.767075955408025
# distortion [dB] for 8-th file: 10.144331248844965
# distortion [dB] for 9-th file: 8.213087946954433
# distortion [dB] for 10-th file: 8.560310424971675
# distortion [dB] for 11-th file: 8.56247367637441
# distortion [dB] for 12-th file: 8.404914680793736
# distortion [dB] for 13-th file: 8.767658228466399
# distortion [dB] for 14-th file: 8.173146795500408
# distortion [dB] for 15-th file: 8.759158116062396
# distortion [dB] for 16-th file: 8.650416314778873
# distortion [dB] for 17-th file: 8.055028116526575
# distortion [dB] for 18-th file: 8.535923937861083
# distortion [dB] for 19-th file: 9.010950373338055
# distortion [dB] for 20-th file: 8.351472036166234
# distortion [dB] for 21-th file: 9.423460703453873
# distortion [dB] for 22-th file: 7.903382340823468
# distortion [dB] for 23-th file: 8.341218358653371
# distortion [dB] for 24-th file: 8.43528923493385
# distortion [dB] for 25-th file: 8.903949193266824
# distortion [dB] for 26-th file: 8.132666104818904
# distortion [dB] for 27-th file: 8.626052114622635
# distortion [dB] for 28-th file: 8.514538031885548
# distortion [dB] for 29-th file: 9.1975088897681
# distortion [dB] for 30-th file: 8.932828494860795
# distortion [dB] for 31-th file: 8.772080648390697
# distortion [dB] for 32-th file: 8.437868105769018
# distortion [dB] for 33-th file: 8.124996205046227
# distortion [dB] for 34-th file: 9.552465899561339
# distortion [dB] for 35-th file: 8.365223299364313
# distortion [dB] for 36-th file: 8.419828445040498
# distortion [dB] for 37-th file: 9.139573082530275
# distortion [dB] for 38-th file: 8.44643519998035
# distortion [dB] for 39-th file: 8.975291137588389
# distortion [dB] for 40-th file: 9.27443833878639
# distortion [dB] for 41-th file: 8.907645651188307
# distortion [dB] for 42-th file: 8.54882761356825
# distortion [dB] for 43-th file: 8.180612097834933
# distortion [dB] for 44-th file: 8.45734745595822
# distortion [dB] for 45-th file: 8.180909225262885
# distortion [dB] for 46-th file: 8.7580477969529
# ## alignment codeap into target length using given twfs ##
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_jnt_mcep_138_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_jnt_codeap_138_.pickle'>
# ## alignment mcep 0-th and silence ##
# 1-th joint feature extraction starts.
# distortion [dB] for 1-th file: 8.207733848761386
# distortion [dB] for 2-th file: 8.485748153843412
# distortion [dB] for 3-th file: 9.056249342531538
# distortion [dB] for 4-th file: 8.179873625170218
# distortion [dB] for 5-th file: 8.785214547532505
# distortion [dB] for 6-th file: 8.537519219108123
# distortion [dB] for 7-th file: 7.900649035176679
# distortion [dB] for 8-th file: 8.465556067593223
# distortion [dB] for 9-th file: 8.60692096256672
# distortion [dB] for 10-th file: 8.867869870128256
# distortion [dB] for 11-th file: 8.345942850699682
# distortion [dB] for 12-th file: 8.881259954910286
# distortion [dB] for 13-th file: 7.6478490983323315
# distortion [dB] for 14-th file: 8.364455854267588
# distortion [dB] for 15-th file: 7.993775592225587
# distortion [dB] for 16-th file: 8.121427447186413
# distortion [dB] for 17-th file: 7.9140799033338824
# distortion [dB] for 18-th file: 8.076862294040998
# distortion [dB] for 19-th file: 9.002849571551547
# distortion [dB] for 20-th file: 8.625808029536786
# distortion [dB] for 21-th file: 8.558824013076155
# distortion [dB] for 22-th file: 8.755888255061077
# distortion [dB] for 23-th file: 8.67953875761925
# distortion [dB] for 24-th file: 9.174977427218975
# distortion [dB] for 25-th file: 8.972441298341176
# distortion [dB] for 26-th file: 8.216214994596264
# distortion [dB] for 27-th file: 7.976406415578424
# distortion [dB] for 28-th file: 9.078885321616495
# distortion [dB] for 29-th file: 8.891934636264601
# distortion [dB] for 30-th file: 8.847533776297528
# distortion [dB] for 31-th file: 8.688612314489802
# distortion [dB] for 32-th file: 8.491171827672767
# distortion [dB] for 33-th file: 8.177222563553375
# distortion [dB] for 34-th file: 8.722148030092075
# distortion [dB] for 35-th file: 8.319058668004988
# distortion [dB] for 36-th file: 8.477159186326897
# distortion [dB] for 37-th file: 8.071698274584072
# distortion [dB] for 38-th file: 7.845227251878195
# distortion [dB] for 39-th file: 7.619007947624458
# distortion [dB] for 40-th file: 8.25323336184446
# distortion [dB] for 41-th file: 7.628143889359308
# distortion [dB] for 42-th file: 8.227293660664786
# distortion [dB] for 43-th file: 8.090619468831624
# distortion [dB] for 44-th file: 7.3321052157383395
# distortion [dB] for 45-th file: 7.716319365892014
# distortion [dB] for 46-th file: 8.533070720918566
# /anaconda3/lib/python3.5/site-packages/sklearn/mixture/base.py:237: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)
# 2-th joint feature extraction starts.
# distortion [dB] for 1-th file: 8.36779528432658
# distortion [dB] for 2-th file: 10.247293332089464
# distortion [dB] for 3-th file: 9.181599144670566
# distortion [dB] for 4-th file: 9.85915297921402
# distortion [dB] for 5-th file: 9.713594385619277
# distortion [dB] for 6-th file: 8.625122373978312
# distortion [dB] for 7-th file: 9.20352923259314
# distortion [dB] for 8-th file: 9.624975053475207
# distortion [dB] for 9-th file: 8.755388971664072
# distortion [dB] for 10-th file: 10.45564756275065
# distortion [dB] for 11-th file: 9.436967521101527
# distortion [dB] for 12-th file: 9.192848486886023
# distortion [dB] for 13-th file: 8.755048520626953
# distortion [dB] for 14-th file: 7.770842642919245
# distortion [dB] for 15-th file: 10.039618572310797
# distortion [dB] for 16-th file: 8.367367500730426
# distortion [dB] for 17-th file: 9.308197568178894
# distortion [dB] for 18-th file: 9.360204144573354
# distortion [dB] for 19-th file: 12.266104867955564
# distortion [dB] for 20-th file: 9.50136529224251
# distortion [dB] for 21-th file: 10.298236571456668
# distortion [dB] for 22-th file: 9.501706996204096
# distortion [dB] for 23-th file: 9.06893854409765
# distortion [dB] for 24-th file: 9.434792283987566
# distortion [dB] for 25-th file: 10.127512616640754
# distortion [dB] for 26-th file: 9.474078636074013
# distortion [dB] for 27-th file: 9.65160872157925
# distortion [dB] for 28-th file: 9.935612269570493
# distortion [dB] for 29-th file: 8.396371089968504
# distortion [dB] for 30-th file: 10.565197249299302
# distortion [dB] for 31-th file: 8.989065920574038
# distortion [dB] for 32-th file: 9.680836603012533
# distortion [dB] for 33-th file: 9.26741808557099
# distortion [dB] for 34-th file: 10.139551693320731
# distortion [dB] for 35-th file: 8.997049446054033
# distortion [dB] for 36-th file: 9.931203661684576
# distortion [dB] for 37-th file: 9.825182202936535
# distortion [dB] for 38-th file: 9.254275296933615
# distortion [dB] for 39-th file: 8.188496655239026
# distortion [dB] for 40-th file: 9.03549893002534
# distortion [dB] for 41-th file: 8.750326548228276
# distortion [dB] for 42-th file: 9.202645869855983
# distortion [dB] for 43-th file: 9.820235357681584
# distortion [dB] for 44-th file: 8.866144032067059
# distortion [dB] for 45-th file: 7.478561396690567
# distortion [dB] for 46-th file: 9.026564598364216
# 3-th joint feature extraction starts.
# distortion [dB] for 1-th file: 8.589119038716468
# distortion [dB] for 2-th file: 9.18123735818457
# distortion [dB] for 3-th file: 9.382428983230415
# distortion [dB] for 4-th file: 9.610572450589816
# distortion [dB] for 5-th file: 8.995956853241314
# distortion [dB] for 6-th file: 9.159335531601394
# distortion [dB] for 7-th file: 9.751088512582127
# distortion [dB] for 8-th file: 9.251218941324229
# distortion [dB] for 9-th file: 8.565771614316619
# distortion [dB] for 10-th file: 9.339877227171009
# distortion [dB] for 11-th file: 8.397188271366424
# distortion [dB] for 12-th file: 9.257656231622388
# distortion [dB] for 13-th file: 9.841160623864765
# distortion [dB] for 14-th file: 8.046992852354254
# distortion [dB] for 15-th file: 9.281588112285414
# distortion [dB] for 16-th file: 9.185126287690643
# distortion [dB] for 17-th file: 8.777223057277666
# distortion [dB] for 18-th file: 9.32725666728677
# distortion [dB] for 19-th file: 10.08017683007816
# distortion [dB] for 20-th file: 10.024160460120246
# distortion [dB] for 21-th file: 9.121781207790594
# distortion [dB] for 22-th file: 9.370538343857763
# distortion [dB] for 23-th file: 8.415539238051235
# distortion [dB] for 24-th file: 9.67900428049996
# distortion [dB] for 25-th file: 9.861579771816995
# distortion [dB] for 26-th file: 9.440885111570749
# distortion [dB] for 27-th file: 8.92988339756102
# distortion [dB] for 28-th file: 9.171847803384782
# distortion [dB] for 29-th file: 9.540089343239618
# distortion [dB] for 30-th file: 9.00766269298632
# distortion [dB] for 31-th file: 9.186104752350813
# distortion [dB] for 32-th file: 9.148376935029958
# distortion [dB] for 33-th file: 8.433446149180591
# distortion [dB] for 34-th file: 9.931499137738756
# distortion [dB] for 35-th file: 9.586589755728252
# distortion [dB] for 36-th file: 9.866537528970545
# distortion [dB] for 37-th file: 8.502851151498035
# distortion [dB] for 38-th file: 8.928753097796458
# distortion [dB] for 39-th file: 8.713726748807245
# distortion [dB] for 40-th file: 8.628624253892237
# distortion [dB] for 41-th file: 9.78259086910716
# distortion [dB] for 42-th file: 9.155964538158095
# distortion [dB] for 43-th file: 8.448167257980481
# distortion [dB] for 44-th file: 10.006348124326472
# distortion [dB] for 45-th file: 7.781941179469471
# distortion [dB] for 46-th file: 8.849155762511314
# ## alignment codeap into target length using given twfs ##
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_jnt_mcep_184_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_jnt_codeap_184_.pickle'>
# ## alignment mcep 0-th and silence ##
# 1-th joint feature extraction starts.
# distortion [dB] for 1-th file: 8.45556279353665
# distortion [dB] for 2-th file: 8.643481091375406
# distortion [dB] for 3-th file: 8.217768764376386
# distortion [dB] for 4-th file: 8.411922468396988
# distortion [dB] for 5-th file: 8.72018661772813
# distortion [dB] for 6-th file: 8.85445607588161
# distortion [dB] for 7-th file: 8.784653896670935
# distortion [dB] for 8-th file: 9.88974895626202
# distortion [dB] for 9-th file: 8.40000928636941
# distortion [dB] for 10-th file: 8.070100655079477
# distortion [dB] for 11-th file: 8.640886878160293
# distortion [dB] for 12-th file: 9.245488301546368
# distortion [dB] for 13-th file: 8.345923094691146
# distortion [dB] for 14-th file: 8.867474933467394
# distortion [dB] for 15-th file: 8.825092180577093
# distortion [dB] for 16-th file: 8.480488661465545
# distortion [dB] for 17-th file: 7.8934032890492345
# distortion [dB] for 18-th file: 8.453345540563284
# distortion [dB] for 19-th file: 8.738833118882312
# distortion [dB] for 20-th file: 10.30498097065018
# distortion [dB] for 21-th file: 9.06796499331058
# distortion [dB] for 22-th file: 9.25002625624555
# distortion [dB] for 23-th file: 8.833531515241525
# distortion [dB] for 24-th file: 9.013719657709693
# distortion [dB] for 25-th file: 9.606809187284474
# distortion [dB] for 26-th file: 8.203365473615152
# distortion [dB] for 27-th file: 9.142907145409756
# distortion [dB] for 28-th file: 8.60389535418232
# distortion [dB] for 29-th file: 9.784825263112461
# distortion [dB] for 30-th file: 9.317979668244899
# distortion [dB] for 31-th file: 9.28931560441992
# distortion [dB] for 32-th file: 9.347680530729487
# distortion [dB] for 33-th file: 9.570187020031787
# distortion [dB] for 34-th file: 9.214421353601516
# distortion [dB] for 35-th file: 8.388527540584693
# distortion [dB] for 36-th file: 8.17731398149571
# distortion [dB] for 37-th file: 8.977865854820395
# distortion [dB] for 38-th file: 8.750717302964768
# distortion [dB] for 39-th file: 7.811600221866164
# distortion [dB] for 40-th file: 8.370718419089734
# distortion [dB] for 41-th file: 8.028259141245833
# distortion [dB] for 42-th file: 8.623341491551363
# distortion [dB] for 43-th file: 8.757016593653438
# distortion [dB] for 44-th file: 8.222413251854933
# distortion [dB] for 45-th file: 9.446761385788637
# distortion [dB] for 46-th file: 10.173177403062917
# 2-th joint feature extraction starts.
# distortion [dB] for 1-th file: 9.298966281674453
# distortion [dB] for 2-th file: 9.414859604841347
# distortion [dB] for 3-th file: 9.735954780864411
# distortion [dB] for 4-th file: 8.857262047551568
# distortion [dB] for 5-th file: 9.51269266747176
# distortion [dB] for 6-th file: 9.14651076752938
# distortion [dB] for 7-th file: 9.873149825457217
# distortion [dB] for 8-th file: 9.961458154763394
# distortion [dB] for 9-th file: 10.025060972260269
# distortion [dB] for 10-th file: 10.034861658739235
# distortion [dB] for 11-th file: 9.291712989078357
# distortion [dB] for 12-th file: 8.529264510014839
# distortion [dB] for 13-th file: 8.30463670592919
# distortion [dB] for 14-th file: 9.937494197188903
# distortion [dB] for 15-th file: 10.26899967776966
# distortion [dB] for 16-th file: 9.099358895902402
# distortion [dB] for 17-th file: 8.494371748143779
# distortion [dB] for 18-th file: 8.665866361091355
# distortion [dB] for 19-th file: 10.29418386896949
# distortion [dB] for 20-th file: 9.01409798182886
# distortion [dB] for 21-th file: 9.001562160236201
# distortion [dB] for 22-th file: 9.716567894256217
# distortion [dB] for 23-th file: 9.243511790618236
# distortion [dB] for 24-th file: 9.192941607721776
# distortion [dB] for 25-th file: 8.484495470640406
# distortion [dB] for 26-th file: 9.253427054570498
# distortion [dB] for 27-th file: 10.074206755423653
# distortion [dB] for 28-th file: 10.665506891164162
# distortion [dB] for 29-th file: 9.497563600483728
# distortion [dB] for 30-th file: 10.131010192948716
# distortion [dB] for 31-th file: 10.050713054010544
# distortion [dB] for 32-th file: 9.145372810184622
# distortion [dB] for 33-th file: 8.883319629015958
# distortion [dB] for 34-th file: 9.991094562481022
# distortion [dB] for 35-th file: 9.635326779987539
# distortion [dB] for 36-th file: 9.64874780068592
# distortion [dB] for 37-th file: 10.088156753795579
# distortion [dB] for 38-th file: 9.393399121675467
# distortion [dB] for 39-th file: 9.998537689921934
# distortion [dB] for 40-th file: 9.283151879998318
# distortion [dB] for 41-th file: 8.993861424548419
# distortion [dB] for 42-th file: 9.430717314344914
# distortion [dB] for 43-th file: 9.144298551259835
# distortion [dB] for 44-th file: 10.655143701792401
# distortion [dB] for 45-th file: 9.500620638514853
# distortion [dB] for 46-th file: 9.323410881373386
# 3-th joint feature extraction starts.
# distortion [dB] for 1-th file: 8.814528735836223
# distortion [dB] for 2-th file: 9.291409377802367
# distortion [dB] for 3-th file: 9.204194050144382
# distortion [dB] for 4-th file: 8.631025135722943
# distortion [dB] for 5-th file: 9.009727401317331
# distortion [dB] for 6-th file: 8.317543403769696
# distortion [dB] for 7-th file: 9.315030285927554
# distortion [dB] for 8-th file: 9.566966275677128
# distortion [dB] for 9-th file: 9.344585612524348
# distortion [dB] for 10-th file: 9.146359176609952
# distortion [dB] for 11-th file: 9.024887154836517
# distortion [dB] for 12-th file: 8.3263813513983
# distortion [dB] for 13-th file: 8.136371352739868
# distortion [dB] for 14-th file: 8.012234771442785
# distortion [dB] for 15-th file: 10.383987019705057
# distortion [dB] for 16-th file: 8.438236400098845
# distortion [dB] for 17-th file: 8.385869508691574
# distortion [dB] for 18-th file: 8.504482464881736
# distortion [dB] for 19-th file: 9.520236569728471
# distortion [dB] for 20-th file: 8.09495543609157
# distortion [dB] for 21-th file: 8.779171856947448
# distortion [dB] for 22-th file: 9.004891461168976
# distortion [dB] for 23-th file: 8.640018190201184
# distortion [dB] for 24-th file: 9.446415616274582
# distortion [dB] for 25-th file: 8.264149891050277
# distortion [dB] for 26-th file: 9.577374257353716
# distortion [dB] for 27-th file: 9.53606388141118
# distortion [dB] for 28-th file: 9.2490679749759
# distortion [dB] for 29-th file: 8.826121260752618
# distortion [dB] for 30-th file: 9.04227550148911
# distortion [dB] for 31-th file: 9.10664079986552
# distortion [dB] for 32-th file: 9.732849100446549
# distortion [dB] for 33-th file: 8.605800378918119
# distortion [dB] for 34-th file: 9.980748654134766
# distortion [dB] for 35-th file: 8.71047708248302
# distortion [dB] for 36-th file: 8.92169111710717
# distortion [dB] for 37-th file: 9.490445671459517
# distortion [dB] for 38-th file: 8.612376230156439
# distortion [dB] for 39-th file: 9.184497561534751
# distortion [dB] for 40-th file: 9.195169004349248
# distortion [dB] for 41-th file: 8.688746382985892
# distortion [dB] for 42-th file: 8.783298199911167
# distortion [dB] for 43-th file: 8.85201482272611
# distortion [dB] for 44-th file: 9.49547851899025
# distortion [dB] for 45-th file: 10.350771267089407
# distortion [dB] for 46-th file: 9.120836601193343
# ## alignment codeap into target length using given twfs ##
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_jnt_mcep_230_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_jnt_codeap_230_.pickle'>
# ## alignment mcep 0-th and silence ##
# 1-th joint feature extraction starts.
# distortion [dB] for 1-th file: 8.130732738208494
# distortion [dB] for 2-th file: 7.994957384746292
# distortion [dB] for 3-th file: 8.05630664461772
# distortion [dB] for 4-th file: 8.120501142586633
# distortion [dB] for 5-th file: 7.910701028861008
# distortion [dB] for 6-th file: 8.009087365952759
# distortion [dB] for 7-th file: 8.270681537804604
# distortion [dB] for 8-th file: 7.801135450717884
# distortion [dB] for 9-th file: 8.107915833255285
# distortion [dB] for 10-th file: 7.974587995559721
# distortion [dB] for 11-th file: 7.724545869503716
# distortion [dB] for 12-th file: 8.292668735345273
# distortion [dB] for 13-th file: 7.625538522875896
# distortion [dB] for 14-th file: 8.025512217794962
# distortion [dB] for 15-th file: 7.705267879064512
# distortion [dB] for 16-th file: 7.420773513788395
# distortion [dB] for 17-th file: 7.500293160579853
# distortion [dB] for 18-th file: 7.94752411903998
# distortion [dB] for 19-th file: 7.49639544403686
# distortion [dB] for 20-th file: 7.7718150637606165
# distortion [dB] for 21-th file: 8.076019714667927
# distortion [dB] for 22-th file: 7.916177839411784
# distortion [dB] for 23-th file: 7.7178411001307134
# distortion [dB] for 24-th file: 8.080403768828036
# distortion [dB] for 25-th file: 8.028760952468204
# distortion [dB] for 26-th file: 8.174849372993393
# distortion [dB] for 27-th file: 7.511932126148294
# distortion [dB] for 28-th file: 7.733350737336102
# distortion [dB] for 29-th file: 8.412832590306737
# distortion [dB] for 30-th file: 7.549293347227661
# distortion [dB] for 31-th file: 8.04128603256864
# distortion [dB] for 32-th file: 8.196521982040839
# distortion [dB] for 33-th file: 7.5673236801272985
# distortion [dB] for 34-th file: 8.014450540238315
# distortion [dB] for 35-th file: 7.860849195681906
# distortion [dB] for 36-th file: 8.203772564289816
# distortion [dB] for 37-th file: 7.811561285221572
# distortion [dB] for 38-th file: 8.10730325629838
# distortion [dB] for 39-th file: 7.333008474406224
# distortion [dB] for 40-th file: 7.956347512234737
# distortion [dB] for 41-th file: 8.079018505260361
# distortion [dB] for 42-th file: 8.227373803803546
# distortion [dB] for 43-th file: 8.87972172587882
# distortion [dB] for 44-th file: 7.799110095949047
# distortion [dB] for 45-th file: 7.8371782129796275
# distortion [dB] for 46-th file: 8.52861883537659
# 2-th joint feature extraction starts.
# distortion [dB] for 1-th file: 8.837963443509862
# distortion [dB] for 2-th file: 8.647543916859034
# distortion [dB] for 3-th file: 9.984481048904884
# distortion [dB] for 4-th file: 9.406818364425064
# distortion [dB] for 5-th file: 10.049967514502974
# distortion [dB] for 6-th file: 10.522314104365435
# distortion [dB] for 7-th file: 10.345973788736682
# distortion [dB] for 8-th file: 7.903353659196299
# distortion [dB] for 9-th file: 9.082015755857725
# distortion [dB] for 10-th file: 9.915486541912747
# distortion [dB] for 11-th file: 8.073601894007126
# distortion [dB] for 12-th file: 8.584037399758888
# distortion [dB] for 13-th file: 8.329056605029873
# distortion [dB] for 14-th file: 9.35347251178935
# distortion [dB] for 15-th file: 9.861407752724752
# distortion [dB] for 16-th file: 8.739825564290259
# distortion [dB] for 17-th file: 9.13664911709562
# distortion [dB] for 18-th file: 8.7536153633255
# distortion [dB] for 19-th file: 8.737401384070814
# distortion [dB] for 20-th file: 8.88653743266294
# distortion [dB] for 21-th file: 9.812866041357925
# distortion [dB] for 22-th file: 8.481432710082181
# distortion [dB] for 23-th file: 8.405263867941345
# distortion [dB] for 24-th file: 8.988436040782027
# distortion [dB] for 25-th file: 7.912453609080441
# distortion [dB] for 26-th file: 7.773611297932121
# distortion [dB] for 27-th file: 8.242365253378669
# distortion [dB] for 28-th file: 8.961381220352248
# distortion [dB] for 29-th file: 8.917520668117866
# distortion [dB] for 30-th file: 9.570068242942925
# distortion [dB] for 31-th file: 8.961644370318036
# distortion [dB] for 32-th file: 8.269462825918108
# distortion [dB] for 33-th file: 8.278939593576613
# distortion [dB] for 34-th file: 9.293337341151547
# distortion [dB] for 35-th file: 8.923475083054267
# distortion [dB] for 36-th file: 8.301056418334351
# distortion [dB] for 37-th file: 7.571755618147421
# distortion [dB] for 38-th file: 9.644361300453282
# ...
# distortion [dB] for 21-th file: 8.414209792229963
# distortion [dB] for 22-th file: 8.574267849002537
# distortion [dB] for 23-th file: 7.192933613749907
# distortion [dB] for 24-th file: 8.981474139632862
# distortion [dB] for 25-th file: 8.05869934461494
# distortion [dB] for 26-th file: 8.1167296790724
# distortion [dB] for 27-th file: 8.477257337065824
# distortion [dB] for 28-th file: 8.686171759357705
# distortion [dB] for 29-th file: 8.814076784539012
# distortion [dB] for 30-th file: 8.93814198211964
# distortion [dB] for 31-th file: 8.973678627478998
# distortion [dB] for 32-th file: 8.826629860209922
# distortion [dB] for 33-th file: 8.468468982015182
# distortion [dB] for 34-th file: 9.076956056284125
# distortion [dB] for 35-th file: 8.512220513107701
# distortion [dB] for 36-th file: 8.551940079266368
# distortion [dB] for 37-th file: 8.789622963618669
# distortion [dB] for 38-th file: 8.008726382687485
# distortion [dB] for 39-th file: 9.38482105710648
# distortion [dB] for 40-th file: 8.170264298402339
# distortion [dB] for 41-th file: 9.33580045854704
# distortion [dB] for 42-th file: 8.561414111982401
# distortion [dB] for 43-th file: 8.565532043462719
# distortion [dB] for 44-th file: 8.428649129507743
# distortion [dB] for 45-th file: 8.677965016700803
# distortion [dB] for 46-th file: 9.347650852943467
# ## alignment codeap into target length using given twfs ##
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_jnt_mcep_874_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_jnt_codeap_874_.pickle'>
# ## alignment mcep 0-th and silence ##
# 1-th joint feature extraction starts.
# distortion [dB] for 1-th file: 8.177552045477661
# distortion [dB] for 2-th file: 8.008169829304638
# distortion [dB] for 3-th file: 7.611665768140262
# distortion [dB] for 4-th file: 7.20598272975974
# distortion [dB] for 5-th file: 7.932928765571272
# distortion [dB] for 6-th file: 7.781182827952331
# distortion [dB] for 7-th file: 7.506688407186501
# distortion [dB] for 8-th file: 7.736147329670824
# distortion [dB] for 9-th file: 7.6991039209503995
# distortion [dB] for 10-th file: 7.513517818218981
# distortion [dB] for 11-th file: 7.356636064531047
# distortion [dB] for 12-th file: 7.83564251583446
# distortion [dB] for 13-th file: 7.247074305706306
# distortion [dB] for 14-th file: 7.979317385802561
# distortion [dB] for 15-th file: 7.018324941337
# distortion [dB] for 16-th file: 7.8969080228871364
# distortion [dB] for 17-th file: 7.173768282410255
# distortion [dB] for 18-th file: 7.21344587407712
# distortion [dB] for 19-th file: 7.671098711745058
# distortion [dB] for 20-th file: 7.837123600861537
# distortion [dB] for 21-th file: 8.036345481288032
# distortion [dB] for 22-th file: 7.586168402742496
# distortion [dB] for 23-th file: 7.818330023834344
# distortion [dB] for 24-th file: 7.630546993916136
# distortion [dB] for 25-th file: 7.9192955303902375
# distortion [dB] for 26-th file: 6.99793891196521
# distortion [dB] for 27-th file: 7.431943329351106
# distortion [dB] for 28-th file: 7.460500655405431
# distortion [dB] for 29-th file: 8.243139367604272
# distortion [dB] for 30-th file: 7.143824699836452
# distortion [dB] for 31-th file: 7.56381316211838
# distortion [dB] for 32-th file: 7.682820646732882
# distortion [dB] for 33-th file: 7.367552573596768
# distortion [dB] for 34-th file: 7.49913593795736
# distortion [dB] for 35-th file: 7.202972713421103
# distortion [dB] for 36-th file: 6.881443494348155
# distortion [dB] for 37-th file: 7.621968592629754
# distortion [dB] for 38-th file: 8.252004560859431
# distortion [dB] for 39-th file: 8.507886662841102
# distortion [dB] for 40-th file: 7.576528680656721
# distortion [dB] for 41-th file: 7.845211539700007
# distortion [dB] for 42-th file: 7.485823454627367
# distortion [dB] for 43-th file: 7.7143241168353
# distortion [dB] for 44-th file: 7.19077031064335
# distortion [dB] for 45-th file: 6.6333630806795325
# distortion [dB] for 46-th file: 7.4494914544618736
# 2-th joint feature extraction starts.
# distortion [dB] for 1-th file: 9.064661067681405
# distortion [dB] for 2-th file: 8.31897887838783
# distortion [dB] for 3-th file: 8.961793939708919
# distortion [dB] for 4-th file: 9.28923586213876
# distortion [dB] for 5-th file: 8.894569010705016
# distortion [dB] for 6-th file: 8.05267155937149
# distortion [dB] for 7-th file: 9.29077770929319
# distortion [dB] for 8-th file: 8.629820084115867
# distortion [dB] for 9-th file: 8.454056660321037
# distortion [dB] for 10-th file: 9.350512896105597
# distortion [dB] for 11-th file: 8.609641427167311
# distortion [dB] for 12-th file: 8.534820707176237
# distortion [dB] for 13-th file: 8.337412856327632
# distortion [dB] for 14-th file: 7.678045524556314
# distortion [dB] for 15-th file: 8.615248602736715
# distortion [dB] for 16-th file: 8.122717860328489
# distortion [dB] for 17-th file: 7.624296643584246
# distortion [dB] for 18-th file: 8.494981796117367
# distortion [dB] for 19-th file: 8.63697881994101
# distortion [dB] for 20-th file: 7.676080473367617
# distortion [dB] for 21-th file: 8.425326773740121
# distortion [dB] for 22-th file: 8.207871703728479
# distortion [dB] for 23-th file: 8.090273592746916
# distortion [dB] for 24-th file: 9.11799205109997
# distortion [dB] for 25-th file: 9.037883157381037
# distortion [dB] for 26-th file: 9.137340775927317
# distortion [dB] for 27-th file: 9.07306302155667
# distortion [dB] for 28-th file: 8.922977856393144
# distortion [dB] for 29-th file: 8.159176060695016
# distortion [dB] for 30-th file: 9.255033946943511
# distortion [dB] for 31-th file: 8.40134761859671
# distortion [dB] for 32-th file: 8.59587481679304
# distortion [dB] for 33-th file: 8.06542066487283
# distortion [dB] for 34-th file: 8.869186074456449
# distortion [dB] for 35-th file: 8.976363161238801
# distortion [dB] for 36-th file: 8.720819264884152
# distortion [dB] for 37-th file: 9.327993458365764
# distortion [dB] for 38-th file: 8.941075778774678
# distortion [dB] for 39-th file: 8.828652533043693
# distortion [dB] for 40-th file: 8.9218875564893
# distortion [dB] for 41-th file: 8.97470035255706
# distortion [dB] for 42-th file: 9.189263523138662
# distortion [dB] for 43-th file: 8.566505987676928
# distortion [dB] for 44-th file: 8.990052319939256
# distortion [dB] for 45-th file: 8.707447821074064
# distortion [dB] for 46-th file: 8.863061930485284
# 3-th joint feature extraction starts.
# distortion [dB] for 1-th file: 9.752813568841425
# distortion [dB] for 2-th file: 8.270398859155163
# distortion [dB] for 3-th file: 9.250222879037675
# distortion [dB] for 4-th file: 10.41163156434495
# distortion [dB] for 5-th file: 9.269017043290471
# distortion [dB] for 6-th file: 8.879301453737243
# distortion [dB] for 7-th file: 10.109328247396093
# distortion [dB] for 8-th file: 8.617862084758308
# distortion [dB] for 9-th file: 8.265632638689905
# distortion [dB] for 10-th file: 9.21821459709879
# distortion [dB] for 11-th file: 9.231187194064507
# distortion [dB] for 12-th file: 9.086159351909961
# distortion [dB] for 13-th file: 8.880530119117443
# distortion [dB] for 14-th file: 7.82222541794999
# distortion [dB] for 15-th file: 8.641732347982346
# distortion [dB] for 16-th file: 8.331564779913105
# distortion [dB] for 17-th file: 8.195706028122983
# distortion [dB] for 18-th file: 8.778551761619934
# distortion [dB] for 19-th file: 8.863295925252713
# distortion [dB] for 20-th file: 7.507008224655626
# distortion [dB] for 21-th file: 8.136790006420918
# distortion [dB] for 22-th file: 8.53212515727589
# distortion [dB] for 23-th file: 7.632267162690225
# distortion [dB] for 24-th file: 8.769037548316705
# distortion [dB] for 25-th file: 9.113856151601576
# distortion [dB] for 26-th file: 10.199856690865866
# distortion [dB] for 27-th file: 8.99904790708098
# distortion [dB] for 28-th file: 9.1534977989291
# distortion [dB] for 29-th file: 8.563269268926787
# distortion [dB] for 30-th file: 8.954378476946577
# distortion [dB] for 31-th file: 9.841613924587126
# distortion [dB] for 32-th file: 9.411731430979692
# distortion [dB] for 33-th file: 8.502473365179885
# distortion [dB] for 34-th file: 9.467669346105758
# distortion [dB] for 35-th file: 9.402933041090392
# distortion [dB] for 36-th file: 8.664576275310026
# distortion [dB] for 37-th file: 8.246368674532034
# distortion [dB] for 38-th file: 9.545607438231174
# distortion [dB] for 39-th file: 9.448775325806524
# distortion [dB] for 40-th file: 8.962729703242815
# distortion [dB] for 41-th file: 9.019866618197248
# distortion [dB] for 42-th file: 9.545364357982244
# distortion [dB] for 43-th file: 8.522901972975397
# distortion [dB] for 44-th file: 10.181395172322578
# distortion [dB] for 45-th file: 9.311228699179008
# distortion [dB] for 46-th file: 9.100703800984395
# ## alignment codeap into target length using given twfs ##
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_jnt_mcep_920_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_jnt_codeap_920_.pickle'>
# ## alignment mcep 0-th and silence ##
# 1-th joint feature extraction starts.
# distortion [dB] for 1-th file: 7.6260008561319355
# distortion [dB] for 2-th file: 7.639450312991606
# distortion [dB] for 3-th file: 7.535909242156908
# distortion [dB] for 4-th file: 7.118095341984912
# distortion [dB] for 5-th file: 7.771214547622923
# distortion [dB] for 6-th file: 7.2738325819087
# distortion [dB] for 7-th file: 7.227696173019556
# distortion [dB] for 8-th file: 7.456612443597137
# distortion [dB] for 9-th file: 7.00911122588141
# distortion [dB] for 10-th file: 7.359462017979855
# distortion [dB] for 11-th file: 7.408579112447844
# distortion [dB] for 12-th file: 7.597502029192258
# distortion [dB] for 13-th file: 6.814299718878095
# distortion [dB] for 14-th file: 8.037320421538066
# distortion [dB] for 15-th file: 6.937253686654195
# distortion [dB] for 16-th file: 7.595738173610647
# distortion [dB] for 17-th file: 7.06970849535595
# distortion [dB] for 18-th file: 7.573793370523365
# distortion [dB] for 19-th file: 7.793283327342594
# distortion [dB] for 20-th file: 8.754062349688073
# distortion [dB] for 21-th file: 8.163410882307844
# distortion [dB] for 22-th file: 7.841506687270981
# distortion [dB] for 23-th file: 7.591414663282328
# distortion [dB] for 24-th file: 7.560805015719633
# distortion [dB] for 25-th file: 7.531565664197229
# distortion [dB] for 26-th file: 7.771236534426872
# distortion [dB] for 27-th file: 7.134978253796277
# distortion [dB] for 28-th file: 7.6121620711693865
# distortion [dB] for 29-th file: 7.865926393113994
# distortion [dB] for 30-th file: 7.385070667259474
# distortion [dB] for 31-th file: 7.767591406553106
# distortion [dB] for 32-th file: 8.435395998983063
# distortion [dB] for 33-th file: 7.587525479790432
# distortion [dB] for 34-th file: 8.05671438483039
# distortion [dB] for 35-th file: 7.860393367254318
# distortion [dB] for 36-th file: 7.437770413102429
# distortion [dB] for 37-th file: 7.460922587319579
# distortion [dB] for 38-th file: 7.599792722898309
# distortion [dB] for 39-th file: 7.322240014617089
# distortion [dB] for 40-th file: 7.578355622587347
# distortion [dB] for 41-th file: 7.485653513912465
# distortion [dB] for 42-th file: 7.498409685945954
# distortion [dB] for 43-th file: 7.840276475028744
# distortion [dB] for 44-th file: 7.510966941432114
# distortion [dB] for 45-th file: 7.387061214084467
# distortion [dB] for 46-th file: 7.5667937745551255
# 2-th joint feature extraction starts.
# distortion [dB] for 1-th file: 8.82557562946306
# distortion [dB] for 2-th file: 9.509314610042818
# distortion [dB] for 3-th file: 8.151606380805744
# distortion [dB] for 4-th file: 9.16290875403139
# distortion [dB] for 5-th file: 10.146879798947923
# distortion [dB] for 6-th file: 8.981866656084524
# distortion [dB] for 7-th file: 9.867968931865724
# distortion [dB] for 8-th file: 9.039332114634414
# distortion [dB] for 9-th file: 9.119159733542102
# distortion [dB] for 10-th file: 9.0164840551542
# distortion [dB] for 11-th file: 8.388272053072447
# distortion [dB] for 12-th file: 9.520249321654541
# distortion [dB] for 13-th file: 7.72901427064902
# distortion [dB] for 14-th file: 8.462237415530803
# distortion [dB] for 15-th file: 8.946477758743264
# distortion [dB] for 16-th file: 9.348739675276528
# distortion [dB] for 17-th file: 8.074381474306652
# distortion [dB] for 18-th file: 9.276583203308695
# distortion [dB] for 19-th file: 8.739685258929537
# distortion [dB] for 20-th file: 8.533581143628956
# distortion [dB] for 21-th file: 10.675167138802776
# distortion [dB] for 22-th file: 8.929597966380815
# distortion [dB] for 23-th file: 9.856632583829084
# distortion [dB] for 24-th file: 8.687384409771367
# distortion [dB] for 25-th file: 9.713257134967776
# distortion [dB] for 26-th file: 8.163745716570586
# distortion [dB] for 27-th file: 9.764146254294708
# distortion [dB] for 28-th file: 8.715278476528775
# distortion [dB] for 29-th file: 10.264872051874026
# distortion [dB] for 30-th file: 9.981078150895721
# distortion [dB] for 31-th file: 9.258868662082088
# distortion [dB] for 32-th file: 10.362190340920144
# distortion [dB] for 33-th file: 9.857588645316357
# distortion [dB] for 34-th file: 8.91101329073947
# distortion [dB] for 35-th file: 9.931768299282176
# distortion [dB] for 36-th file: 9.863962494661438
# distortion [dB] for 37-th file: 10.181724689419987
# distortion [dB] for 38-th file: 9.804416293793272
# distortion [dB] for 39-th file: 10.563350362803774
# distortion [dB] for 40-th file: 9.736941915843717
# distortion [dB] for 41-th file: 10.652893542077063
# distortion [dB] for 42-th file: 8.580357351816296
# distortion [dB] for 43-th file: 9.807915341740383
# distortion [dB] for 44-th file: 10.279342289170753
# distortion [dB] for 45-th file: 8.796252843238909
# distortion [dB] for 46-th file: 9.4269111991563
# 3-th joint feature extraction starts.
# distortion [dB] for 1-th file: 9.465133030552833
# distortion [dB] for 2-th file: 9.655878966328203
# distortion [dB] for 3-th file: 8.473024193967111
# distortion [dB] for 4-th file: 8.994908821610679
# distortion [dB] for 5-th file: 9.358731831233372
# distortion [dB] for 6-th file: 9.30030636700842
# distortion [dB] for 7-th file: 8.848689100421618
# distortion [dB] for 8-th file: 9.116905846278096
# distortion [dB] for 9-th file: 9.480186392663201
# distortion [dB] for 10-th file: 9.223874152013709
# distortion [dB] for 11-th file: 8.493799474692066
# distortion [dB] for 12-th file: 8.764376704904969
# distortion [dB] for 13-th file: 8.097207396947633
# distortion [dB] for 14-th file: 8.356579693315771
# distortion [dB] for 15-th file: 8.695255902027478
# distortion [dB] for 16-th file: 9.322917447659789
# distortion [dB] for 17-th file: 8.336897978967569
# distortion [dB] for 18-th file: 8.679360148101
# distortion [dB] for 19-th file: 8.559344847253769
# distortion [dB] for 20-th file: 8.01561077285112
# distortion [dB] for 21-th file: 9.656244020836104
# distortion [dB] for 22-th file: 8.545557221794436
# distortion [dB] for 23-th file: 11.51687284307944
# distortion [dB] for 24-th file: 9.199045753260993
# distortion [dB] for 25-th file: 9.121117757460087
# distortion [dB] for 26-th file: 8.359148923633017
# distortion [dB] for 27-th file: 9.525901767607106
# distortion [dB] for 28-th file: 8.820865562336907
# distortion [dB] for 29-th file: 8.625223641968823
# distortion [dB] for 30-th file: 8.829095537066216
# distortion [dB] for 31-th file: 9.152609999608037
# distortion [dB] for 32-th file: 9.324204276360282
# distortion [dB] for 33-th file: 9.476296647195008
# distortion [dB] for 34-th file: 9.477396302888094
# distortion [dB] for 35-th file: 8.832636919800427
# distortion [dB] for 36-th file: 8.912902033469662
# distortion [dB] for 37-th file: 9.044110972350481
# distortion [dB] for 38-th file: 9.42657281069788
# distortion [dB] for 39-th file: 10.654114111140315
# distortion [dB] for 40-th file: 10.002371742183541
# distortion [dB] for 41-th file: 9.916088105534993
# distortion [dB] for 42-th file: 8.565646206473376
# distortion [dB] for 43-th file: 9.551478154942615
# distortion [dB] for 44-th file: 9.648633172058089
# distortion [dB] for 45-th file: 9.623745929875508
# distortion [dB] for 46-th file: 8.950098109913654
# ## alignment codeap into target length using given twfs ##
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_jnt_mcep_966_.pickle'>
# <_io.BufferedWriter name='./utterance/pre-stored-jp/output/_jnt_codeap_966_.pickle'>

# %%
# 3. make EV-GMM

initgmm, initgmm_codeap = None, None
jnt, jnt_codeap = None, []
for i in range(0, len(mid_mceplist), len(org_mceplist)):
    with open(output_path + "_jnt_mcep_{}_.pickle".format(i), 'rb') as f:  
        temp_jnt = pickle.load(f)
        if jnt is None:
            jnt = temp_jnt
        else:
            jnt = np.r_[jnt, temp_jnt]
    with open(output_path + "_jnt_codeap_{}_.pickle".format(i), 'rb') as f:  
        temp_jnt_codeap = pickle.load(f)
        jnt_codeap.append(temp_jnt_codeap)
        
jnt_codeap = transform_jnt(jnt_codeap)
assert jnt.shape[0] == jnt_codeap.shape[0]

# train initial gmm
initgmm = GMMTrainer()
initgmm.train(jnt)

initgmm_codeap = GMMTrainer()
initgmm_codeap.train(jnt_codeap)

# %%
# get initial gmm params
init_W = initgmm.param.weights_
init_jmean = initgmm.param.means_
init_jcov = initgmm.param.covariances_
sddim = init_jmean.shape[1] // 2
init_meanX = init_jmean[:, :sddim]
init_meanY = init_jmean[:, sddim:]
init_covXX = init_jcov[:, :sddim, :sddim]
init_covXY = init_jcov[:, :sddim, sddim:]
init_covYX = init_jcov[:, sddim:, :sddim]
init_covYY = init_jcov[:, sddim:, sddim:]
fitted_source = init_meanX
fitted_target = init_meanY

# get initial codeap gmm params
init_W_codeap = initgmm_codeap.param.weights_
init_jmean_codeap = initgmm_codeap.param.means_
init_jcov_codeap = initgmm_codeap.param.covariances_
sddim_codeap = init_jmean_codeap.shape[1] // 2
init_meanX_codeap = init_jmean_codeap[:, :sddim_codeap]
init_meanY_codeap = init_jmean_codeap[:, sddim_codeap:]
init_covXX_codeap = init_jcov_codeap[:, :sddim_codeap, :sddim_codeap]
init_covXY_codeap = init_jcov_codeap[:, :sddim_codeap, sddim_codeap:]
init_covYX_codeap = init_jcov_codeap[:, sddim_codeap:, :sddim_codeap]
init_covYY_codeap = init_jcov_codeap[:, sddim_codeap:, sddim_codeap:]
fitted_source_codeap = init_meanX_codeap
fitted_target_codeap = init_meanY_codeap

# %%
depengmm, depengmm_codeap = None, None
depenjnt, depenjnt_codeap = None, None
sv, sv_codeap = [], []
for i in range(0, len(mid_mceplist), len(org_mceplist)):
    with open(output_path + "_jnt_mcep_{}_.pickle".format(i), 'rb') as f:  
        depenjnt = pickle.load(f)
        depengmm = GMMTrainer()
        depengmm.param.weights_ = init_W
        depengmm.param.means_ = init_jmean
        depengmm.param.covariances_ = init_jcov
        depengmm.train(depenjnt)
        sv.append(depengmm.param.means_)
    with open(output_path + "_jnt_codeap_{}_.pickle".format(i), 'rb') as f:  
        depenjnt_codeap = pickle.load(f)
        depengmm_codeap = GMMTrainer()
        depengmm_codeap.param.weights_ = init_W_codeap
        depengmm_codeap.param.means_ = init_jmean_codeap
        depengmm_codeap.param.covariances_ = init_jcov_codeap
        depengmm_codeap.train(depenjnt_codeap)
        sv_codeap.append(depengmm_codeap.param.means_)
sv = np.array(sv)
sv_codeap = np.array(sv_codeap)
np.save(output_path + "_sv", sv)
np.save(output_path + "_sv_codeap", sv_codeap)

# %%
# PCA
n_mix = 64
S = int(len(mid_mceplist) / len(org_mceplist))
assert S == 22

source_component, source_features = sv[:, :, :sddim].reshape(S, n_mix * sddim).shape
source_stdsc = StandardScaler() # standarize
source_X_std = source_stdsc.fit_transform(sv[:, :, :sddim].reshape(S, n_mix * sddim)) # calculate covariance
# do PCA
source_cov = source_X_std.T @ source_X_std / (source_component - 1)
source_W, source_V_pca = np.linalg.eig(source_cov)
# transform data to principal area
source_X_pca = source_X_std @ source_V_pca

target_component, target_features = sv[:, :, sddim:].reshape(S, n_mix * sddim).shape
target_stdsc = StandardScaler() # standarize
target_X_std = target_stdsc.fit_transform(sv[:, :, sddim:].reshape(S, n_mix * sddim)) # calculate covariance
# do PCA
target_cov = target_X_std.T @ target_X_std / (target_component - 1)
target_W, target_V_pca = np.linalg.eig(target_cov)
# transform data to principal area
target_X_pca = target_X_std @ target_V_pca

eigenvectors = source_X_pca.reshape((n_mix, sddim, S)), target_X_pca.reshape((n_mix, sddim, S))
source_bias = np.mean(sv[:, :, :sddim], axis=0)
target_bias = np.mean(sv[:, :, sddim:], axis=0)
biasvectors = source_bias.reshape((n_mix, sddim)), target_bias.reshape((n_mix, sddim))

# %%
# PCA for codeap
source_component_codeap, source_features_codeap = sv_codeap[:, :, :sddim_codeap].reshape(S, n_mix * sddim_codeap).shape
source_stdsc_codeap = StandardScaler() # standarize
source_X_std_codeap = source_stdsc_codeap.fit_transform(sv_codeap[:, :, :sddim_codeap].reshape(S, n_mix * sddim_codeap)) # calculate covariance
# do PCA
source_cov_codeap = source_X_std_codeap.T @ source_X_std_codeap / (source_component_codeap - 1)
source_W_codeap, source_V_pca_codeap = np.linalg.eig(source_cov_codeap)
# transform data to principal area
source_X_pca_codeap = source_X_std_codeap @ source_V_pca_codeap

target_component_codeap, target_features_codeap = sv_codeap[:, :, sddim_codeap:].reshape(S, n_mix * sddim_codeap).shape
target_stdsc_codeap = StandardScaler() # standarize
target_X_std_codeap = target_stdsc_codeap.fit_transform(sv_codeap[:, :, sddim_codeap:].reshape(S, n_mix * sddim_codeap)) # calculate covariance
# do PCA
target_cov_codeap = target_X_std_codeap.T @ target_X_std_codeap / (target_component_codeap - 1)
target_W_codeap, target_V_pca_codeap = np.linalg.eig(target_cov_codeap)
# transform data to principal area
target_X_pca_codeap = target_X_std_codeap @ target_V_pca_codeap

eigenvectors_codeap = source_X_pca_codeap.reshape((n_mix, sddim_codeap, S)), target_X_pca_codeap.reshape((n_mix, sddim_codeap, S))
source_bias_codeap = np.mean(sv_codeap[:, :, :sddim_codeap], axis=0)
target_bias_codeap = np.mean(sv_codeap[:, :, sddim_codeap:], axis=0)
biasvectors_codeap = source_bias_codeap.reshape((n_mix, sddim_codeap)), target_bias_codeap.reshape((n_mix, sddim_codeap))

# %%
# 4. estimate statistic features.
for_convert_source = __same_path + 'input/EJM10/V01/T01/TIMIT/000/*.wav' 
for_convert_target = __same_path + 'adaptation/EJF01/V01/T01/ATR503/A/*.wav'

print("## estimate static fetures ##")

src_f0list = []
src_splist = []
src_mceplist = []
src_aplist = []
src_npowlist = []
src_codeaplist = []
for files in sorted(glob.iglob(for_convert_source, recursive=True)):
    wavf = files
    x, fs = sf.read(wavf)
    x = np.array(x, dtype=np.float)
    x = low_cut_filter(x, fs, cutoff=70)
    assert fs == 16000

    print("extract acoustic featuers: " + wavf)

    f0, sp, ap = feat.analyze(x)
    mcep = feat.mcep()
    npow = feat.npow()
    codeap = feat.codeap()
    
    src_f0list.append(f0)
    src_splist.append(sp)
    src_mceplist.append(mcep)
    src_aplist.append(ap)
    src_npowlist.append(npow)
    src_codeaplist.append(codeap)


tar_f0list = []
tar_mceplist = []
tar_aplist = []
tar_npowlist = []
tar_splist = []
tar_codeaplist = []

for files in sorted(glob.iglob(for_convert_target, recursive=True)):
    wavf = files
    x, fs = sf.read(wavf)
    x = np.array(x, dtype=np.float)
    x = low_cut_filter(x, fs, cutoff=70)
    assert fs == 16000

    print("extract acoustic featuers: " + wavf)

    f0, sp, ap = feat.analyze(x)
    mcep = feat.mcep()
    npow = feat.npow()
    codeap = feat.codeap()
    name, ext = os.path.splitext(wavf)

    tar_f0list.append(f0)
    tar_splist.append(sp)
    tar_mceplist.append(mcep)
    tar_aplist.append(ap)
    tar_npowlist.append(npow)
    tar_codeaplist.append(codeap)
# Out:
# ## estimate static fetures ##
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A11.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A14.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A17.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A18.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A19.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A20.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A21.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A22.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A23.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A24.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A25.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A26.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A27.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A28.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A29.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A30.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A31.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A32.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A33.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A34.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A35.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A36.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A37.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A38.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A39.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A40.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A41.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A42.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A43.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A44.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A45.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A46.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A47.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A48.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A49.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A50.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A51.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A52.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A53.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A54.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A55.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A56.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A57.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A58.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/input/EJM10/V01/T01/TIMIT/000/A59.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/adaptation/EJF01/V01/T01/ATR503/A/A01.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/adaptation/EJF01/V01/T01/ATR503/A/A02.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/adaptation/EJF01/V01/T01/ATR503/A/A03.wav
# extract acoustic featuers: ./utterance/pre-stored-jp/adaptation/EJF01/V01/T01/ATR503/A/A04.wav

# %%
f0stats = F0statistics()
srcf0stats = f0stats.estimate(org_f0list)
tarf0stats = f0stats.estimate(tar_f0list)

gv = GV()
srcgvstats = gv.estimate(org_mceplist)
targvstats = gv.estimate(tar_mceplist)

# %%
# 5. fitting target
epoch = 100

fitgmm = sklearn.mixture.GaussianMixture(n_components=sddim, covariance_type='full', max_iter=100)
fitgmm.weights_ = init_W
print(init_W.shape)
fitgmm.means_ = init_meanY
print(init_meanY.shape)
fitgmm.covariances_ = init_covYY
fitgmm.precisions_cholesky_ = _compute_precision_cholesky(init_covXX, 'full')
fitted_target = None

for i in range(len(tar_mceplist)):
    print("adapt: ", i+1, "/", len(tar_mceplist))
    target = tar_mceplist[i]
    target_pow = target[:, 0]
    target = target[:, 1:]
    for x in range(epoch):
        print("epoch = ", x)
        predict = fitgmm.predict_proba(np.atleast_2d(static_delta(target)))
        print(static_delta(target).shape, predict.shape, target.shape, biasvectors[1][0].shape, sddim)
        
        y = np.sum([predict[:, k: k + 1] * (static_delta(target) - biasvectors[1][k]) for k in range(n_mix)], axis = 1)
        gamma = np.sum(predict, axis = 0)

        left = np.sum([gamma[k] * np.dot(eigenvectors[1][k].T,
                                         np.linalg.solve(fitgmm.covariances_, eigenvectors[1])[k])
                       for k in range(n_mix)], axis=0)
        right = np.sum([np.dot(eigenvectors[1][k].T, 
                               np.linalg.solve(fitgmm.covariances_, y)[k]) 
                        for k in range(n_mix)], axis = 0)
        weight = np.linalg.solve(left, right)

        fitted_target = np.dot(eigenvectors[1], weight) + biasvectors[1]
        fitgmm.means_ = fitted_target
# Out:
# (64,)
# (64, 48)
# adapt:  1 / 4
# epoch =  0
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  1
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# /anaconda3/lib/python3.5/site-packages/sklearn/mixture/gaussian_mixture.py:413: ComplexWarning: Casting complex values to real discards the imaginary part
#   log_prob[:, k] = np.sum(np.square(y), axis=1)
# epoch =  2
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  3
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  4
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  5
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  6
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  7
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  8
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  9
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  10
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  11
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  12
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  13
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  14
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  15
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  16
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  17
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  18
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  19
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  20
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  21
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  22
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  23
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  24
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  25
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  26
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  27
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  28
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  29
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  30
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  31
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  32
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  33
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  34
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  35
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  36
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  37
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  38
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  39
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  40
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  41
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  42
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  43
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  44
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  45
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  46
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  47
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  48
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  49
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  50
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  51
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  52
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  53
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  54
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  55
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  56
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  57
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  58
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  59
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  60
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  61
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  62
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  63
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  64
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  65
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  66
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  67
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  68
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  69
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  70
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  71
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  72
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  73
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  74
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  75
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  76
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  77
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  78
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  79
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  80
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  81
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  82
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  83
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  84
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  85
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  86
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  87
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  88
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  89
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  90
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  91
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  92
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  93
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  94
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  95
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  96
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  97
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  98
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# epoch =  99
# (1211, 48) (1211, 64) (1211, 24) (48,) 48
# adapt:  2 / 4
# epoch =  0
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  1
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  2
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  3
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  4
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  5
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  6
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  7
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  8
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  9
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  10
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  11
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  12
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  13
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  14
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  15
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  16
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  17
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  18
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  19
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  20
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  21
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  22
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  23
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  24
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  25
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  26
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  27
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  28
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  29
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  30
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  31
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  32
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  33
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  34
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  35
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  36
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  37
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  38
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  39
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  40
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  41
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  42
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  43
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  44
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  45
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  46
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  47
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  48
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  49
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  50
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  51
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  52
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  53
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  54
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  55
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  56
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  57
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  58
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  59
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  60
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  61
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  62
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  63
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  64
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  65
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  66
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  67
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  68
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  69
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  70
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  71
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  72
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  73
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  74
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  75
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  76
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  77
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  78
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  79
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  80
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  81
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  82
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  83
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  84
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  85
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  86
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  87
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  88
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  89
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  90
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  91
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  92
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  93
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  94
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  95
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  96
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  97
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  98
# (875, 48) (875, 64) (875, 24) (48,) 48
# epoch =  99
# (875, 48) (875, 64) (875, 24) (48,) 48
# adapt:  3 / 4
# epoch =  0
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  1
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  2
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  3
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  4
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  5
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  6
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  7
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  8
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  9
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  10
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  11
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  12
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  13
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  14
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  15
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  16
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  17
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  18
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  19
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  20
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  21
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  22
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  23
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  24
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  25
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  26
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  27
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  28
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  29
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  30
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  31
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  32
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  33
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  34
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  35
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  36
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  37
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  38
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  39
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  40
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  41
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  42
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  43
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  44
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  45
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  46
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  47
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  48
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  49
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  50
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  51
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  52
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  53
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  54
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  55
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  56
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  57
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  58
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  59
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  60
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  61
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  62
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  63
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  64
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  65
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  66
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  67
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  68
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  69
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  70
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  71
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  72
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  73
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  74
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  75
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  76
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  77
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  78
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  79
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  80
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  81
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  82
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  83
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  84
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  85
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  86
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  87
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  88
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  89
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  90
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  91
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  92
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  93
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  94
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  95
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  96
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  97
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  98
# (945, 48) (945, 64) (945, 24) (48,) 48
# epoch =  99
# (945, 48) (945, 64) (945, 24) (48,) 48
# adapt:  4 / 4
# epoch =  0
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  1
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  2
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  3
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  4
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  5
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  6
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  7
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  8
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  9
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  10
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  11
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  12
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  13
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  14
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  15
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  16
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  17
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  18
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  19
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  20
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  21
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  22
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  23
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  24
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  25
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  26
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  27
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  28
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  29
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  30
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  31
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  32
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  33
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  34
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  35
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  36
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  37
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  38
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  39
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  40
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  41
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  42
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  43
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  44
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  45
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  46
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  47
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  48
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  49
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  50
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  51
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  52
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  53
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  54
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  55
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  56
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  57
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  58
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  59
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  60
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  61
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  62
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  63
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  64
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  65
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  66
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  67
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  68
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  69
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  70
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  71
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  72
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  73
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  74
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  75
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  76
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  77
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  78
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  79
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  80
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  81
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  82
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  83
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  84
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  85
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  86
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  87
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  88
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  89
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  90
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  91
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  92
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  93
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  94
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  95
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  96
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  97
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  98
# (1241, 48) (1241, 64) (1241, 24) (48,) 48
# epoch =  99
# (1241, 48) (1241, 64) (1241, 24) (48,) 48

# %%
def mcepconvert(source, weights, jmean, meanX, covarXX, covarXY, covarYX, covarYY,
                fitted_source, fitted_target):
    """
    """
    M = 64
    # set_pX (like a GMMConverter) 
    px = sklearn.mixture.GaussianMixture(n_components=M, covariance_type='full')
    px.weights_ = weights
    px.means_ = meanX
    px.covariances_ = covarXX
    px.precisions_cholesky_ = _compute_precision_cholesky(covarXX, 'full')
    
    # set_Ab (like a GMMConverter)
    sddim = jmean.shape[1] // 2
    covXXinv = np.zeros((M, sddim, sddim))
    for m in range(M):
        covXXinv[m] = np.linalg.inv(covarXX[m])
    A = np.zeros((M, sddim, sddim))
    b = np.zeros((M, sddim))
    cond_cov_inv = np.zeros((M, sddim, sddim))
    for m in range(M):
        A[m] = covarYX[m] @ covXXinv[m]
        b[m] = fitted_target[m] - A[m] @ meanX[m]
        cond_cov_inv[m] = np.linalg.inv(covarYY[m] - A[m] @ covarXY[m])
    
    # _gmmmap
    T, sddim = source.shape
    wseq = px.predict_proba(source)
    cseq = np.argmax(wseq, axis=1)
    mseq = np.zeros((T, sddim))
    covseq = np.zeros((T, sddim, sddim))
    for t in range(T):
        m = cseq[t]
        mseq[t] = fitted_target[m] + A[m] @ (source[t] - meanX[m])
        covseq[t] = cond_cov_inv[m]
    
    # _mlpg
    T, sddim = mseq.shape
    W = construct_static_and_delta_matrix(T, sddim // 2)
    D = get_diagonal_precision_matrix(T, sddim, covseq)
    WD = W.T @ D
    WDW = WD @ W
    WDM = WD @ mseq.flatten()
    
    output = scipy.sparse.linalg.spsolve(WDW, WDM, use_umfpack=False).reshape(T, sddim // 2)
    
    return output

# %%
temp_mcep = src_mceplist[0]
temp_mcep_0th = temp_mcep[:, 0]
temp_mcep = temp_mcep[:, 1:]
sta_mcep = static_delta(temp_mcep)
output_mfcc = np.array(mcepconvert(sta_mcep, init_W, init_jmean, init_meanX, init_covXX, 
                                   init_covXY, init_covYX, init_covYY, fitted_source, fitted_target))
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:23: ComplexWarning: Casting complex values to real discards the imaginary part
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:34: ComplexWarning: Casting complex values to real discards the imaginary part

# %%
cvmcep = np.c_[temp_mcep_0th, output_mfcc]

# %%
temp_sm = pysptk.mc2sp(cvmcep, 0.42, 1024)
wav = pw.synthesize(src_f0list[0], temp_sm, src_aplist[0], 16000, frame_period=5)
sf.write("temp.wav", wav, 16000)
# Out:
# /anaconda3/lib/python3.5/site-packages/pysptk/conversion.py:154: RuntimeWarning: overflow encountered in exp
#   return np.exp(np.fft.rfft(symc).real)
